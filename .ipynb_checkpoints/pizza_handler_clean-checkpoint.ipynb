# %% [markdown]
# # W207 Final Project Submission
# ### Michael Demertzi and Matt Hayes
#
# <a id="top"></a>
# #### Table of Contents
# <ol>
# <li><a href="#part1">Data Handling</a></li>
# <li><a href="#part2">Feature Engineering</a></li>
# <ul>
# <li>Extra Numeric Features</li>
# <li>Topic Modeling</li>
# <li>Visualizing Features</li><br/>
# </ul>
# <li><a href="#part3">Basic Model Class</a></li>
# <li><a href="#part4">Baseline Model</a></li>
# <ul>
# <li>Pure Baseline</li>
# <li>Baseline Tuned with GridSearchCV</li><br/>
# </ul>
# <li><a href="#part5">Trying Many Different Classifiers</a></li>
# <ul>
# <li><a href="#part5a">Numeric Gaussian NB</a></li>
# <li><a href="#part5b">Numeric Decision Tree</a></li>
# <li><a href="#part5c">Numeric Random Forest</a></li>
# <li><a href="#part5d">Ensemble Random Forest</a></li>
# <li><a href="#part5e">Ensemble Decision Tree</a></li>
# <li><a href="#part5f">Ensemble Gaussian NB</a></li>
# <li><a href="#part5g">Ensemble Logistic Regression</a></li>
# <li><a href="#part5h">Numeric GMM with PCA</a></li>
# <li><a href="#part5i">Ensemble GMM with PCA and Topic Modeling</a></li>
# <li><a href="#part5j">Text Logistic Regression with Preprocessing</a></li>
# <li><a href="#part5k">Mixed Text, Topic and Numeric Logistic Regression with Preprocessing</a></li><br/>
# </ul>
# <li><a href="#part6">Experiments</a></li>
# <ul>
# <li>GridsearchCV Tuners</li>
# <li>GMM and PCA Tuning</li>
# <li>Enhanced Text Processing - Pruning and Nouns</li><br/>
# </ul>
# <li><a href="#part7">Ensembling Attempt</a></li>
# <ul>
# <li><a href="#part7a">Data Helper Scripts</a></li>
# <li><a href="#part7b">Ensembling Script</a></li>
# <li><a href="#part7c">Pipelines and Testing</a></li><br/>
# </ul>
# <li><a href="#part8">Final Submission</a></li>
# <li><a href="#part9">Error Analysis</a></li>
# <ul>
# <li>Checking our final model</li>
# <li>Examining the failures of our best text model</li><br/>
# </ul>

# %%
'''
This cell's function:
Import all libraries that will be needed throughout document
'''
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# General libraries.
import re
import numpy as np
import matplotlib.pyplot as plt
import json
from pprint import pprint
import datetime
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# SK-learn libraries for learning.
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB, MultinomialNB, GaussianNB
from sklearn.grid_search import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.cross_validation import cross_val_score

# SK-learn libraries for feature extraction from text.
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

#preprocessing libraries
import nltk
from nltk.stem import PorterStemmer
#import enchant.checker #CAN't INSTALL THIS SINCE I HAVE 64 BIT PYTHON :( Michael
from nltk.corpus import stopwords
from sklearn.preprocessing import normalize
from sklearn.preprocessing import binarize

# PCA / GMM
import time
from sklearn.decomposition import PCA
from sklearn.decomposition import NMF
from sklearn.cluster import KMeans
from sklearn.mixture import GMM
from matplotlib.colors import LogNorm

print 'import success!'
# Out:
# import success!

# %% [markdown]
# <a id="part1"></a>
# ## 1. Data Handling

# %%
class Data_handler():
    
    if __name__ == "__main__":
        dfTrain_full = pd.DataFrame()
        dfTest = pd.DataFrame()
        dfTrain = pd.DataFrame()
        dfDev = pd.DataFrame()
        trainColumnNames = []
        testColumnNames = []
    
    def initialize_data(self,train_json, test_json, prop_train):
        #Load in data as panda dataframes
        with open(train_json,'r') as fp: 
            json_data = json.load(fp)
        self.dfTrain_full = pd.io.json.json_normalize(json_data)

        with open(test_json,'r') as fp: 
            json_data = json.load(fp)
        self.dfTest = pd.io.json.json_normalize(json_data)

        # Set np seed
        np.random.seed(0)

        #Shuffle train data and split into train and dev
        self.dfTrain_full.reindex(np.random.permutation(self.dfTrain_full.index)) #shuffle
        nTrain_full = self.dfTrain_full.shape[0]
        self.dfTrain = self.dfTrain_full[:int(nTrain_full*prop_train)]
        self.dfDev = self.dfTrain_full[int(nTrain_full*prop_train):]
        
        #Save number of observations in train and dev
        nTrain = self.dfTrain.shape[0]
        nDev = self.dfDev.shape[0]

        #Save column names for reference
        self.trainColumnNames = self.dfTrain.columns.tolist()
        self.testColumnNames = self.dfTest.columns.tolist() #Note test features is only a subset!
        
        return nTrain_full, nTrain, nDev ################# WHY DOES THIS GET RETURNED? WHAT IS IT USED FOR?
    
    def getTrainFull(self):
        return self.dfTrain_full   
    def getTest(self):
        return self.dfTest   
    def getTrain(self):
        return self.dfTrain   
    def getDev(self):
        return self.dfDev    
    def getTrainColumnNames(self):
        return self.trainColumnNames   
    def getTestColumnNames(self):
        return self.testColumnNames
    
# Load in our data to master_data. Proportion in train vs dev is set here. Changing it will take effect throughout everything else in the script (the magic of classes!)
master_data = Data_handler()
master_data.initialize_data('train.json', 'test.json',.75)
# Out:
# (4040, 3030, 1010)

# %%
"""
VISUALISATION Cell
"""

def timeVisualizer():
    '''
    Visualize time related trends. Does RAOP get more or less generous over time? 
    Certain times of day? Certain days of week?
    '''
    raise NotImplementedError

def featureImportanceVisualizer(fitted_model):
    '''
    Takes a fitted model with a 'extractFeatureImportance' method
    plots bar graph of features
    see http://matplotlib.org/examples/lines_bars_and_markers/barh_demo.html for plotting example
    '''
    labs,means,std_devs = fitted_model.extractFeatureImportance()
    err = std_devs*1.96 #95th percentile confidence interval
    
    #plot results
    fig = plt.figure(figsize=(15,15))
    y_pos = np.arange(labs.shape[0])
    plt.barh(y_pos, means, xerr=err, align='center', alpha=0.4)
    plt.yticks(y_pos,labs)
    plt.ylabel('Feature')
    plt.xlabel('Importance w/ 95% conf interval')
    plt.title('Feature importance visualizer')
    
    plt.show()
    
def colNamePrint():
    '''
    Just print out TEST column names w indices for ref.
    '''
    c = master_data.getTestColumnNames()
    for i,n in enumerate(c):
        print i, '_',n
    #END    

def visFeatures(data,feature_names,labels):
    '''
    Input: numeric data array and associated names, labels
    
    Plots them.
    -Red is recieved pizza
    -Blue is not recieved pizza
    -Data is balanced between classes for proper visual effect (same amount of examples of each)
    '''
    n_features = data.shape[1]
    #instantiate plot object - SCATTER
    fig = plt.figure(figsize=(10*2,n_features*10/2))
    for i in range(n_features):
        ax = fig.add_subplot(n_features/2+1,2,i+1)
        ax.scatter(data[~labels,i][:sum(labels)],labels[~labels][:sum(labels)]+np.random.random(sum(labels))/1.1,c='blue',alpha=0.05)
        ax.scatter(data[labels,i],labels[labels]+np.random.random(sum(labels))/1.1,c='red',alpha=0.05)
        ax.set_title(feature_names[i])
    
    #instantiate plot object - HISTOGRAM
    fig = plt.figure(figsize=(10,n_features*10))
    for i in range(n_features):
        ax = fig.add_subplot(n_features,1,i+1)
        ax.hist([data[~labels,i],data[labels,i]],50, normed=1,histtype='bar',color=['blue','red'],alpha=0.8)
        ax.set_title(feature_names[i])

# %% [markdown]
# <a id="part2"></a>
# ## 2. Feature Engineering

# %%
class FeatureEngineer():
    '''
    Module that contains some of our feature engineering methods. 
    Does not contain instance variables!
    Outputs np arrays or dataframes as needed
    '''
    def unionText(self,df):
        req_text = df['request_text_edit_aware'].values
        title_text = df['request_title'].values
        merged_text = []
        for i in range(req_text.shape[0]):
            merged_text.append(title_text[i]+' '+req_text[i])
        merged_text_array = np.asarray(merged_text)
        return merged_text_array
        
    def separateTimestamp(self,df):
        '''
        separates time stamp (UTC) into month, day, hour. If user's local time is of interest, 
        use the non UTC data
        input: any dataFrame containing the timestamp data
        '''

        timeStamps = df['unix_timestamp_of_request_utc'].values #numpy array of timestamps
        timeStampsSeparate = [] #init new

        # Loop over timestamps
        for ts in timeStamps:
            # Pull out relevant time info
            d = datetime.datetime.fromtimestamp(ts)
            month = d.strftime("%m")
            day_of_month = d.strftime("%d")
            hour = d.strftime("%H")
            # Append to results
            timeStampsSeparate.append([int(month),int(day_of_month),int(hour)])
        
        #manually create labels
        labels = ['month','day_of_month','hour']
        #convert from python list to ndarray
        return np.asarray(timeStampsSeparate), labels

    def newTimeInfo(self,df):
        '''
        New expressions of time e.g day of week
        '''
        
        timeStamps = df['unix_timestamp_of_request'].values #LOCAL time
        timeStampsSeparate = [] #init new

        # Loop over timestamps
        for ts in timeStamps:
            # Pull out relevant time info
            d = datetime.datetime.fromtimestamp(ts)
            day_of_week = d.isoweekday()
            local_time =d.strftime("%H")
            present_day = datetime.date(2015,4,20) #blaze it
            community_age = (present_day-d.date()).days
            # Append to results
            timeStampsSeparate.append([int(day_of_week),int(local_time),int(community_age)])
        #manually create labels
        labels = ['day_of_week','local_time','community_age']       
        #convert from python list to ndarray
        return np.asarray(timeStampsSeparate), labels
        
    def selectedNumericFeatures(self,df):
        '''
        Some hand picked numeric features that seem to work well in logistic regression
        Dependency: separateTimestamp
        '''
        colNames = [master_data.getTestColumnNames()[i] for i in [5,7,8,9]] #hand picked to be plausible, not optimal 
        #numeric data
        dfNum = df[colNames].values
        #convert time stamp into nice format
        dfTime, labelsTime = self.separateTimestamp(df)
        #merge
        combinedData = np.column_stack((dfNum,dfTime))
        combinedLabels = colNames+labelsTime
        return combinedData, combinedLabels
    
    def allNumericFeatures(self,df):
        '''
        All of the numeric features that come standard.
        Dependency: separateTimestamp, newTimeInfo
        '''
        colNames = [master_data.getTestColumnNames()[i] for i in [4,5,6,7,8,9,10,12,13]] 
        #numeric data
        dfNum = df[colNames].values
        #convert time stamp into nice format
        dfTime, labelsTime = self.separateTimestamp(df)
        #new time
        dfTimeNew, labelsTimeNew = self.newTimeInfo(df)
        #merge
        combinedData = np.column_stack((dfNum,dfTime))#,dfTimeNew))
        combinedLabels = colNames+labelsTime#+labelsTimeNew
        return combinedData, combinedLabels
    
    def simpleNewFeatures(self,df):
        '''
        Basic self explanatory features.
        Input: whole df
        '''
        
        #From text
        title_length = [len(t) for t in df['request_title'].values]
        req_length = [len(t) for t in df['request_text_edit_aware'].values]
        avg_word_length = [float(len(t))/len(t.split(' ')) for t in df['request_text_edit_aware'].values] #complexity of lang
        title_caps_norm = [sum(1 for c in t if c.isupper())/(float(len(t))+1) for t in df['request_title'].values]
        req_caps_norm = [sum(1 for c in t if c.isupper())/(float(len(t))+1) for t in df['request_text_edit_aware'].values]
        #num_all_caps_words
        #num_repeated_words #perhaps normalize and/or remove shorter words
        
        ###special chars in text
        num_numbers_norm = [sum(1 for c in t if c.isdigit())/(float(len(t))+1) for t in df['request_text_edit_aware'].values]
        num_currency_chars_norm = [sum(1 for c in t if c in '$')/(float(len(t))+1) for t in df['request_text_edit_aware'].values]
        num_exclamation_norm = [sum(1 for c in t if c in '!')/(float(len(t))+1) for t in df['request_text_edit_aware'].values]
        num_commas_norm = [sum(1 for c in t if c in ',')/(float(len(t))+1) for t in df['request_text_edit_aware'].values]
        ######has hyperlink?? 
        
        ###language
        #grammar_errors #normalized for request length
        #spelling_errors #normalized for request length
        
        f = np.asarray([title_length,
                          req_length,
                          avg_word_length,
                          title_caps_norm,
                          req_caps_norm,
                          num_numbers_norm,
                          num_currency_chars_norm,
                          num_exclamation_norm,
                          num_commas_norm]).T
        
        labels = ['title_length',
                  'req_length',
                  'avg_word_length',
                  'title_caps_norm',
                  'req_caps_norm',
                  'num_numbers_norm',
                  'num_currency_chars_norm',
                  'num_exclamation_norm',
                  'num_commas_norm']
        
        return f,labels
    
    def augNumericFeatures(self,df):
        f1, l1 = self.simpleNewFeatures(df)
        f2, l2 = self.allNumericFeatures(df)
        return np.column_stack((f1,f2)),l1+l2
    
    def gourmetNumericFeatures(self,df):
        '''
        Implement ideas gained from visual inspection of data
        Mostly binarizing where possible to densify feature space.
        '''

        f,l = fe.augNumericFeatures(df)

        toBinary = {'num_commas_norm':0.0025,
                    'requester_account_age_in_days_at_request':7,
                    'requester_days_since_first_post_on_raop_at_request':10,
                    'requester_number_of_comments_in_raop_at_request':1,
                    'requester_number_of_posts_on_raop_at_request':0,
                    'day_of_month':15,
                    'hour':5}

        f2 = []
        for edit in toBinary:
            for i in range(len(l)):
                if edit==l[i]:
                    f[:,i] = binarize(f[:,i],toBinary[edit])
                    l[i] = l[i] + '_BINARIZED'

            return f,l
        
    def reducedEnsemble(self,df):
        '''
        reduced set of numeric + ensemble features for use in DT or RF 
        '''
        colNames = [master_data.getTestColumnNames()[i] for i in [4,10,12,13]] 
        #numeric data
        f_num = df[colNames].values
        f,l = self.simpleNewFeatures(df)
        l_new = np.asarray(l)[[0,1,2,3,4,8]].tolist()
        f_new = f[:,[0,1,2,3,4,8]]
        #merge
        combinedData = np.column_stack((f_num,f_new))
        combinedLabels = colNames+l_new
        return combinedData, combinedLabels
        
        
    def customNGrams(self,df):
        '''
        N Grams built by intuition
        '''
        #pay_it_forward = some regex to find phrase "pay it forward"
        raise NotImplementedError

    def vectorize(self,raw_fit,raw_predict,params={}):
        # transform the train data
        vectorizer_train = CountVectorizer(**params)
        fit_data = vectorizer_train.fit_transform(raw_fit)
        feature_names = vectorizer_train.get_feature_names()
        # transform the dev data using the same vocab
        predict_data = vectorizer_train.transform(raw_predict)     # 'transform' function will preserve previous vocab
        return fit_data, predict_data, feature_names

    def reVectorizer(self,fitted_model,n_keep = 100):
        '''
        This vectorizer prunes features away based on the importance rated by fitted_model.
        '''
        #extract data from fitted_model
        c = fitted_model.c
        importances = c.coef_[0,:]
        old_names = fitted_model.feature_names
        old_fit_data = fitted_model.fit_data
        old_predict_data = fitted_model.predict_data

        #sort features by importance
        ind = np.argsort(-np.absolute(importances))[:n_keep]

        #create pruned feature set
        new_names = np.asarray(old_names)[ind]
        new_fit = old_fit_data[:,ind]
        new_predict = old_predict_data[:,ind]
        
        return new_fit,new_predict,new_names

    def extractNouns(self,df):
        '''
        Experiment: Extract nouns only
        input: dataframe
        output: just like fe.unionText but only containing the nouns.
        WARNING: Takes about 3 minutes on Training set.
        '''
        train_text = fe.unionText(df)
        train_nouns = []
        t0 = time.time()
        for i in range(train_text.shape[0]):
            tags = nltk.pos_tag(nltk.word_tokenize(train_text[i]))
            bag_of_nouns = ' '.join([word for word,t in tags if t in ['NN','NNS']])
            train_nouns.append(bag_of_nouns)
        print 'Nouns extracted in: ', time.time()-t0
        return np.array(train_nouns)
    
    def deciles(self,np_array):
        '''
        converts features to deciles.
        MOSTLY useful for converting topic modelling coefficients to something usable!
        '''
        a = np_array
        b = a.copy()
        #convert to deciles
        for p in np.linspace(0,90,10):
            lower = np.percentile(a, p, axis=0)
            upper = np.percentile(a, (p+10), axis=0)
            b[np.logical_and(a>=lower,a<=upper)] = p/10
        return b

class TopicModeller(object):
    '''
    topic modeller gets special attention because it takes so long to calculate! Just do it once and be done with it.
    '''
    def __init__(self,dfFit,dfPredict):
        self.dfFit = dfFit
        self.dfPredict = dfPredict
        
        #run algo
        self.modelTopics()
        
        #print results
        
    
    def modelTopics(self):
        '''
        Topic modelling using sklearn NMF model
        '''

        #Hyperparameters
        n_features = 1000
        components = 10 #number of topics to fit (10 is suggested by paper I read)

        #get nouns from previous feature engineer
        t0 = time.time()
        print "Extracting nouns... this may take a few mins"
        fit = fe.extractNouns(self.dfFit)
        predict = fe.extractNouns(self.dfPredict)
        print "Nouns extracted in %3.2fs" % (time.time() - t0)

        #vectorize, negating highest and lowest frequency terms
        t0 = time.time()
        print "Vectorizing with TFIDF"
        vec = TfidfVectorizer(max_df=0.90, min_df=2, max_features=n_features,stop_words='english')
        fit_tf = vec.fit_transform(fit)
        predict_tf = vec.transform(predict)
        feature_names = vec.get_feature_names()
        print "Vectorized in %3.2fs" % (time.time() - t0)

        #Fit NMF
        t0 = time.time()
        print "Fitting topics.. this may take a while"
        nmf_model = NMF(n_components=components)
        fit_topics = nmf_model.fit_transform(fit_tf)
        print "Topics fitted in %3.2fs." % (time.time() - t0)
        #Transform predict data
        predict_topics = nmf_model.transform(predict_tf)
        
        #save data!
        self.fit_topics = fit_topics
        self.predict_topics = predict_topics
        self.feature_names = feature_names
        self.nmf_model = nmf_model
        
    def topicKeywords(self,n=30):
        '''
        Prints the topics and most important keywords according to an NMF model
        input: a fitted NMF
        '''
        print "\nTOP WORDS ASSOCIATED WITH EACH TOPIC"
        for i in range(self.nmf_model.components_.shape[0]):
            print "Topic #",i+1
            ind = np.argsort(-self.nmf_model.components_[i])
            n_comps = '\t'.join(np.asarray(self.feature_names)[ind][:n+1])
            print n_comps, '\n'

# %% [markdown]
# The following is a summary of the simple numeric features we engineered. There are a couple more we would have liked to have done but ran out of time:
#     *Image embedded in post (binary)
#     *Grammar errors
#     *Spelling errors

# %%
'''
Initiate Feature Engineer 
'''
fe = FeatureEngineer()

print "ALL ENGINEERED/STOCK NUMERIC FEATURES:"
print '\n'.join(fe.augNumericFeatures(master_data.getTrain())[1])
# Out:
# ALL ENGINEERED/STOCK NUMERIC FEATURES:
# title_length
# req_length
# avg_word_length
# title_caps_norm
# req_caps_norm
# num_numbers_norm
# num_currency_chars_norm
# num_exclamation_norm
# num_commas_norm
# requester_account_age_in_days_at_request
# requester_days_since_first_post_on_raop_at_request
# requester_number_of_comments_at_request
# requester_number_of_comments_in_raop_at_request
# requester_number_of_posts_at_request
# requester_number_of_posts_on_raop_at_request
# requester_number_of_subreddits_at_request
# requester_upvotes_minus_downvotes_at_request
# requester_upvotes_plus_downvotes_at_request
# month
# day_of_month
# hour

# %% [markdown]
# Regarding numeric features: We suspect that systematic investigation of each feature with better summary statistics would have been fruitful. Regrettably spent more time engineering new features and trying to get classifiers to talk to each other.
#
# Still, the following visualizations (scroll down for the Histograms) were useful in guaging the data.

# %%
def examineAugFeatures():
    data,feature_names = fe.augNumericFeatures(master_data.getTrain())
    labels = master_data.getTrain()['requester_received_pizza'].values.astype(bool)
    visFeatures(data,feature_names,labels)
    '''
    FROM SCATTER:
    The visualization isn't useful for many of the numeric features, but is good for some
    Clearly we have some data quality issues with some features:
    -extreme outliers on avg_word_length,req_caps_norm,num_currency_chars_norm,and the 2 karma metrics.
    None of the features seem super obvious- effect sizes are small.
    
    FROM HISTOGRAM:
    Suggested encoding of features:
    title_length: continuous
    req_length: continuous
    num_commas_norm: Binary (>0.0025)
    requester_account_age_in_days_at_request: Binary (>7)
    requester_days_since_first_post_on_raop_at_request: Binary (>10)
    requester_number_of_comments_in_raop_at_request: Binary (>1)
    requester_number_of_posts_on_raop_at_request: Binary (>0)
    day_of_month: Binary (>15)
    hour: Binary (>5)
    community_age: VERY useful, continuous or therabouts
    '''
examineAugFeatures()
# Out:
# (3030L, 24L)
# 24

# %% [raw]
# Topic modelling was really fun. We took the idea from Althoff et al, who analyze a larger verion of teh RAOP data set.
# https://cs.stanford.edu/~althoff/raop-dataset/altruistic_requests_icwsm.pdf
#
# We used NMF to decompose the text into 10 topics as suggested by the paper. The topics have clear themes- one topic is about money problems, another is about studying for finals.
#
# Filtering out all non-nouns greatly sped up the topic modelling, improved the subjective separation of topics and slightly improved results when fed to a LogisticRegression model. The filtering was done using NLTK (see preceding TopicModeller class).

# %%
"""
Initiate Topic Modellers
NOTE: Takes some time, so don't recalc if you don't need to!
""" 
#developmentTM = TopicModeller(master_data.getTrain(),master_data.getDev()) #Run these once, and once only! Takes about 6 mins.
#finalTM = TopicModeller(master_data.getTrainFull(),master_data.getTest())
# Out:
# Extracting nouns... this may take a few mins
# Nouns extracted in:  270.028000116
# Nouns extracted in:  109.044000149
# Nouns extracted in 379.13s
# Vectorizing with TFIDF
# Vectorized in 0.16s
# Fitting topics.. this may take a while
# Topics fitted in 259.56s.
# C:\Anaconda\lib\site-packages\sklearn\decomposition\nmf.py:533: UserWarning: Iteration limit reached during fit
#   warnings.warn("Iteration limit reached during fit")

# %%
developmentTM.topicKeywords()
# Out:
# TOP WORDS ASSOCIATED WITH EACH TOPIC
# Topic # 1
# pizza	random	story	sob	act	friends	right	boyfriend	return	cheese	weekend	people	guys	order	life	hut	cash	person	friday	lt	sounds	mood	stranger	redditor	money	kind	guy	internet	pepperoni	reddit	picture
#
# Topic # 2
# job	months	paycheck	month	weeks	check	luck	interview	time	year	days	rent	unemployment	end	pay	couple	bit	ramen	lot	work	bills	rice	cheer	life	school	jobs	yesterday	offer	situation	income	phone
#
# Topic # 3
# today	account	http	bank	birthday	card	tomorrow	days	cash	gift	debit	lunch	thanks	pie	reddit	fridge	help	check	morning	dollars	picture	credit	code	couple	dinner	verification	work	awesome	friends	cents	bit
#
# Topic # 4
# day	work	home	today	tomorrow	pay	kind	lunch	sick	night	hours	thing	morning	month	pasta	car	brother	hour	edit	reading	life	mother	weeks	pepperoni	school	man	humanity	jobs	help	care	history
#
# Topic # 5
# food	money	house	days	month	couple	help	rent	stamps	bills	weeks	gas	parents	place	weekend	pantry	funds	yesterday	fridge	home	roommate	mom	apartment	dog	till	moment	town	situation	brother	work	groceries
#
# Topic # 6
# hungry	broke	favor	paycheck	bit	thanks	rent	pie	car	friday	fridge	cash	till	students	girl	help	need	wallet	sick	yesterday	shop	town	girlfriend	interview	im	hours	jobless	home	yr	kinda	daughter
#
# Topic # 7
# time	family	friend	help	night	thanks	kids	story	people	way	year	sob	house	years	home	husband	tomorrow	friends	dinner	wife	things	lot	subreddit	area	reading	mom	life	need	bills	children	car
#
# Topic # 8
# student	college	finals	school	semester	students	meal	money	summer	time	study	ramen	exams	broke	classes	university	home	year	loan	loans	need	tuition	kid	apartment	tomorrow	weekend	test	paper	thanks	break	books
#
# Topic # 9
# week	work	ramen	favor	rent	payday	rice	weeks	thanks	groceries	paycheck	days	title	end	couple	pay	check	school	noodles	car	home	money	half	girlfriend	dollars	summer	way	bank	lunch	pick	wife
#
# Topic # 10
# tonight	dinner	ramen	thanks	rent	broke	noodles	months	night	kids	pie	month	boys	sub	tomorrow	daughter	shot	rice	edit	movie	amp	pasta	couple	cash	goodness	payday	fam	deposit	sick	evening	wife

# %%
'''
Visually examine topics much like earlier numeric data.
'''

def examineTopics():
    data,feature_names = fe.deciles(developmentTM.fit_topics), ['Topic '+str(i) for i in range(1,11)]
    print data.shape
    labels = master_data.getTrain()['requester_received_pizza'].values.astype(bool)
    visFeatures(data,feature_names,labels)

print ("""Topics 2, 3, 7, 9 and 10 appear most useful. 
       However we can't know that the topic will emerge in same order at test time so we can't simply prune.""")
    
examineTopics()
# Out:
# Topics 2, 3, 7, 9 and 10 appear most useful.
#        However we can't know that the topic will emerge in same order at test time so we can't simply prune.
# (3030L, 10L)

# %% [markdown]
# <a id="part3"></a>
# ## 3. Basic Model Class

# %%
class Model(object):
    '''
    In Model and child classes, we use Fit and Predict for data sets to avoid confusion. These 
    can actually be train, dev or test in various combinations depending on how it is initialized.
    '''
    def __init__(self,dfFit,dfPredict):
        self.dfFit = dfFit
        self.dfPredict = dfPredict
        self.fit_labels = self.dfFit['requester_received_pizza'].values
    
    def test(self,criteria=metrics.roc_auc_score):
        try:
            predict_labels = self.dfPredict['requester_received_pizza'].values
            return criteria(predict_labels,self.prediction)
        except:
            return "Failed! 'dfPredict' has no labels, no prediction present or invalid test criteria"
    
    def writeSubmission(self,fileName='submit_to_kaggle.csv'):
        try:
            '''
            Ensure the test data hasn't been shuffled or your labels won't match the request_id's.
            '''
            #extract request_id so we can match against predictions for submission to kaggle
            req = self.dfPredict['request_id']
            #make prediction into a pandas series
            print self.prediction.astype(int)
            pred_series = pd.Series(self.prediction.astype(int),name="requester_received_pizza")
            #now join into data frame
            out = pd.concat([req,pred_series], axis=1)
            #write data frame to csv (using kaggles sample submission csv for correct format)
            out.to_csv(fileName,index=False)
            print "Written to File!"
        except:
            return "Failed! Is 'dfPredict' the test set?"
    
    def getPrediction(self):
        return self.prediction
    
    def gridSearch(self,params):
        '''
        implement GridSearchCV in class
        '''
        gs = GridSearchCV(self.classifier(),params,scoring='roc_auc')
        gs.fit(self.fit_data,self.fit_labels)
        print gs.best_params_
        return gs
    
    def crossVal(self,params=None):
        '''
        Implement cross validation score
        '''
        scores = cross_val_score(self.classifier(**params),
                                 self.fit_data,
                                 self.fit_labels,
                                 cv=4, scoring='roc_auc')
        print "Mean AUC:", np.mean(scores)
        return scores

# %% [markdown]
# <a id="part4"></a>
# ## 4. Baseline Model

# %% [raw]
# We thought a simple Logistic Regression would make an appropriate baseline because:
#     *It is an obvious minimal-effort attempt to use the data - especially because we are just using the request text, vectorized.
#     *It is a good platform for feature and error analysis. We fit many models with various combinations of features and tried to understand what the regression was doing to the weights, and tried to gain intuition as to why some documents (which we'd print out from time to time) were misclassified.
#
# We ended up getting results that were quite counterintuitive and hard (for us) to understand. It was surprisingly hard to improve the model beyond simply using every available word and minimal weight penalization.

# %%
class Baseline(Model):
    '''
    Any model just needs to implicitly inherit the model class
    -Test this with baseline(master_data.getTrain(),master_data.getDev()) and
                   baseline.test()
    -Generate output with baseline(master_data.getTrainFull(),master_data.getTest()) and
                         baseline.writeSubmission()
    
    This is the first model we submitted to Kaggle
    '''
    def __init__(self,dfFit,dfPredict,params={}):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = LogisticRegression
        self.params = params
        #how to process data
        raw_fit = fe.unionText(self.dfFit)
        raw_predict = fe.unionText(self.dfPredict)
        self.fit_data, self.predict_data, self.feature_names = fe.vectorize(raw_fit,raw_predict,params)

    def run_model(self):
        self.prediction = self.log_reg()

    def log_reg(self):
        self.c = self.classifier()
        self.c.fit(self.fit_data, self.fit_labels)
        lor_pred = self.c.predict(self.predict_data)
        # Return the prediction matrix, coefficients
        return lor_pred

    def extractFeatureImportance(self,n=50):
        importances = self.c.coef_[0,:]
        stdDev = np.zeros(importances.shape)
        ind = np.argsort(-np.absolute(importances))[:n]
        importances_sorted = importances[ind]
        importances_names = np.asarray(self.feature_names)[ind]
        stdDev_sorted = stdDev[ind]
        return importances_names,importances_sorted,stdDev_sorted

# %%
baseline_model = Baseline(master_data.getTrain(),master_data.getDev())
baseline_model.run_model()
print baseline_model.test()
# Out:
# 0.529516225216

# %%
class BaselineTuned(Baseline):
    '''
    Overhaul log_reg function to include tuned params
    params found by running tuneBaseline() in Experiments cell
    '''
    def log_reg(self):
        self.c = self.classifier(penalty='l1',C=0.092)
        self.c.fit(self.fit_data, self.fit_labels)
        lor_pred = self.c.predict(self.predict_data)
        # Return the prediction matrix, coefficients
        return lor_pred

# %%
'''
Using the suggested GridsearchCV parameters... which ended up worse... thanks Gridsearch!
'''
baseline_t_model = BaselineTuned(master_data.getTrain(),master_data.getDev())
baseline_t_model.run_model()
print baseline_t_model.test()
# Out:
# 0.505440949079

# %% [markdown]
# <a id="part5"></a>
# ## 5. Trying Many Different Classifiers

# %% [markdown]
# <a id="part5a"></a>
# ### a. Numeric Gaussian NB

# %% [markdown]
# Note you can see the data fed to each model by looking at the __init__ function. Here we use "fe.augNumericFeatures" which is found in our FeatureEngineer class at the beginning of document. In this example we are using the augmented (self-engineered) set of numeric features.
#
# We carried out various comparisons between different feature sets and models but removed most of it for presentation.

# %%
class NumericModel(Model):
    '''
    Simple models with numeric data straight out of df
    '''
    def __init__(self,dfFit,dfPredict):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = GaussianNB
        #how to process data
        self.fit_data,self.feature_names = fe.augNumericFeatures(self.dfFit)
        self.predict_data,_ = fe.augNumericFeatures(self.dfPredict)
    
    def run_model(self):
        #predict
        self.prediction = self.classify()    
    
    def classify(self):
        self.c = self.classifier()
        self.c.fit(self.fit_data, self.fit_labels)
        return self.c.predict(self.predict_data) 
    
    def extractFeatureImportance(self):
        '''
        WARNING: Not sure if this is meaningful since data is not normalized.
        May only be meaningful with text data because that represents word counts.
        '''
        pass
        '''
        importances = self.c.coef_[0,:]
        stdDev = np.zeros(importances.shape)
        ind = np.argsort(-np.absolute(importances))
        importances_sorted = importances[ind]
        importances_names = np.asarray(self.feature_names)[ind]
        stdDev_sorted = stdDev[ind]
        return importances_names,importances_sorted,stdDev_sorted
        '''

# %%
nm = NumericModel(master_data.getTrain(),master_data.getDev())
nm.run_model()
print nm.test()
# Out:
# 0.532247254458

# %%
'''
Let's try the same thing, normalizing the numeric data before fitting the classifier.
'''
nm = NumericModel(master_data.getTrain(),master_data.getDev())
nm.fit_data, nm.predict_data = normalize(nm.fit_data), normalize(nm.predict_data)
nm.run_model()
print nm.test()
print "worse performance? Why?" #Note this was confirmed to *often* be the case on different cross val sets.
# Out:
# 0.513916375093
# worse performance? Why?

# %%
'''
Try again with "fe.gourmetNumericFeatures", and/or "fe.reducedEnsemble"
which gives a reduced feature space based on extracting Random Forest feature importances and inspecting histograms.
A few combinations of features were tried but not in a systematic way.
'''
nm = NumericModel(master_data.getTrain(),master_data.getDev())
nm.fit_data,nm.feature_names = fe.gourmetNumericFeatures(nm.dfFit)
nm.predict_data,_ = fe.gourmetNumericFeatures(nm.dfPredict)
nm.run_model()
print nm.test()
print "no dice!"
# Out:
# 0.530933194011
# no dice!

# %% [markdown]
# <a id="part5b"></a>
# ### b. Numeric Decision Tree

# %% [markdown]
# On The Decision Trees and Random Forests:
#
# The idea of using these was going to be as a level 2 classifier to merge our text and numeric models. That is, regressions and GMMs were to feed into this classifier for final output.
#
# Hence, we required a nonlinear classifer that had potential to work well with only a few (good) features. Enter Trees!
#
# This didn't work well. Depending on hyperparams, the trees either ignored the level 1 class output, producing a bad model, or produced a model that was exactly as good as the best level 1 class on it's own. We put this down to lack of understanding on how to tune the trees and analyse errors.

# %%
class DecisionTreeModel(Model):
    '''
    Basic decision tree. Runs on numeric features
    '''
    def __init__(self,dfFit,dfPredict):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = DecisionTreeClassifier
        #how to process data
        self.fit_data,self.feature_names = fe.augNumericFeatures(self.dfFit)
        self.predict_data,_ = fe.augNumericFeatures(self.dfPredict)
    
    def run_model(self):
        self.prediction = self.classify()  
    
    def classify(self):
        self.c = self.classifier(criterion='entropy',max_depth=5) #criterion can be 'gini' or 'entropy'
        self.c.fit(self.fit_data, self.fit_labels)
        return self.c.predict(self.predict_data) 
        
    def extractFeatureImportance(self):
        importances = self.c.feature_importances_
        stdDev = np.zeros(importances.shape)
        ind = np.argsort(-importances)
        importances_sorted = importances[ind]
        importances_names = np.asarray(self.feature_names)[ind]
        stdDev_sorted = stdDev[ind]
        return importances_names,importances_sorted,stdDev_sorted

# %%
#Run test of decision tree
decision_tree_model = DecisionTreeModel(master_data.getTrain(),master_data.getDev())
decision_tree_model.run_model()
print decision_tree_model.test()
# Out:
# 0.538485083567

# %% [markdown]
# <a id="part5c"></a>
# ### c. Numeric Random Forest

# %%
class RandomForestModel(Model):
    '''
    Random Forest   
    '''
    def __init__(self,dfFit,dfPredict):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = RandomForestClassifier
        #how to process data
        self.fit_data,self.feature_names = fe.augNumericFeatures(self.dfFit)
        self.predict_data,_ = fe.augNumericFeatures(self.dfPredict)
    
    def run_model(self):
        #predict
        self.prediction = self.classify()  
    
    def classify(self):
        self.c = self.classifier(**{'criterion': 'entropy','n_estimators':100})#,
                                    #max_features=10) #criterion can be 'gini' or 'entropy'
        self.c.fit(self.fit_data, self.fit_labels)
        return self.c.predict(self.predict_data) 
    
    def extractFeatureImportance(self):
        stdDev = np.std([dTree.feature_importances_ for dTree in self.c],axis=0)
        importances = self.c.feature_importances_
        ind = np.argsort(-importances)
        importances_sorted = importances[ind]
        importances_names = np.asarray(self.feature_names)[ind]
        stdDev_sorted = stdDev[ind]
        return importances_names,importances_sorted,stdDev_sorted

# %%
rf_model = RandomForestModel(master_data.getTrain(),master_data.getDev())
rf_model.run_model()
print rf_model.test()
# Out:
# 0.526946155186

# %% [markdown]
# <a id="part5d"></a>
# ### d. Ensemble Random Forest

# %%
class EnsembleForest(RandomForestModel):
    '''
    RF that incorporates text data via votes of another classifier
    '''
    def __init__(self,dfFit,dfPredict):
        RandomForestModel.__init__(self,dfFit,dfPredict)
        #how to process data
        self.ensembleFeatures()
    
    def ensembleFeatures(self):
        '''
        creates self.fit_data, self.predict_data and self.feature_names
        '''
        ###FIT features
        f1,l1 = fe.augNumericFeatures(self.dfFit) 
        #add outputs of tuned baseline classifier
        lvl1class = Baseline(self.dfFit,self.dfFit) #note predicts it's own train data!
        lvl1class.run_model()
        f2 = lvl1class.getPrediction()          
        l2 = ['lvl1classifier']
        self.fit_data = np.column_stack((f1,f2))
        ###FEATURE Labels
        self.feature_names = l1+l2
        ###PREDICT features
        f1,_ = fe.augNumericFeatures(self.dfPredict)
        lvl1class = Baseline(self.dfFit,self.dfPredict) #this time predict on predict data
        lvl1class.run_model()
        f2 = lvl1class.getPrediction()          
        self.predict_data = np.column_stack((f1,f2))

# %%
ef_model = EnsembleForest(master_data.getTrain(),master_data.getDev())
ef_model.run_model()
print ef_model.test()
# Out:
# 0.529516225216

# %% [markdown]
# <a id="part5e"></a>
# ### e. Ensemble Decision Tree

# %%
class EnsembleTree(DecisionTreeModel):
    '''
    DT that incorporates text data via votes of another classifier
    '''
    def __init__(self,dfFit,dfPredict):
        DecisionTreeModel.__init__(self,dfFit,dfPredict)
        #how to process data
        self.ensembleFeatures()
    
    def ensembleFeatures(self):
        '''
        creates self.fit_data, self.predict_data and self.feature_names
        '''
        ###FIT features
        f1,l1 = fe.reducedEnsemble(self.dfFit) 
        #add outputs of tuned baseline classifier
        lvl1class = Baseline(self.dfFit,self.dfFit) #note predicts it's own train data!
        lvl1class.run_model()
        f2 = lvl1class.getPrediction()          
        l2 = ['lvl1classifier']
        self.fit_data = np.column_stack((f1,f2))
        ###FEATURE Labels
        self.feature_names = l1+l2
        ###PREDICT features
        f1,_ = fe.reducedEnsemble(self.dfPredict)
        lvl1class = Baseline(self.dfFit,self.dfPredict) #this time predict on predict data
        lvl1class.run_model()
        f2 = lvl1class.getPrediction()          
        self.predict_data = np.column_stack((f1,f2))

# %%
edt_model = EnsembleTree(master_data.getTrain(),master_data.getDev())
edt_model.run_model()
print edt_model.test()
# Out:
# 0.527545134546

# %% [markdown]
# <a id="part5f"></a>
# ### f. Ensemble Gaussian NB

# %%
class EnsembleNB(NumericModel):
    '''
    NB that incorporates text data via votes of another classifier
    '''
    def __init__(self,dfFit,dfPredict):
        NumericModel.__init__(self,dfFit,dfPredict)
        #how to process data
        self.ensembleFeatures()
    
    def ensembleFeatures(self):
        '''
        creates self.fit_data, self.predict_data and self.feature_names
        '''
        ###FIT features
        f1,l1 = fe.reducedEnsemble(self.dfFit) 
        #add outputs of tuned baseline classifier
        lvl1class = Baseline(self.dfFit,self.dfFit) #note predicts it's own train data!
        lvl1class.run_model()
        f2 = lvl1class.getPrediction()          
        l2 = ['lvl1classifier']
        self.fit_data = np.column_stack((f1,f2))
        ###FEATURE Labels
        self.feature_names = l1+l2
        ###PREDICT features
        f1,_ = fe.reducedEnsemble(self.dfPredict)
        lvl1class = Baseline(self.dfFit,self.dfPredict) #this time predict on predict data
        lvl1class.run_model()
        f2 = lvl1class.getPrediction()          
        self.predict_data = np.column_stack((f1,f2))

# %%
egnb_model = EnsembleNB(master_data.getTrain(),master_data.getDev())
egnb_model.run_model()
print egnb_model.test()
# Out:
# 0.528202164769

# %% [markdown]
# <a id="part5g"></a>
# ### g. Logistic Regression - With numeric features

# %% [markdown]
# This marks the beginning of extending the Baseline Logistic Regression model by:
#     * Including feature engineered and stock numeric features
#     * Reducing vocab without affecting performance:
#         -First, applying min_df and max_df to vectorizer
#         -Second, removing all but n 'most important' features as rated by a previously fitted LR.
#
# The end game is to try to reduce the vectorized words to a reasonable number (less than 250) so that there was "room" in the model for:
# * numeric features
# * topic features
# * ensembling other classifiers
#
# A secondary objective was to get TfidfVectorizer working as well as CountVectorizer. We never made that happen, and not sure why.
#
# See Experiments section for more details.

# %%
class LRMixed(Baseline):
    '''
    Merge Baseline Model features (pruned) with numeric features.
    '''
    def __init__(self,dfFit,dfPredict,mindf=1,maxdf=1.0,baseline_params={},ensemble_params={}):
        #hyperparams
        self.baseline_params = baseline_params
        self.ensemble_params = ensemble_params
        Baseline.__init__(self,dfFit,dfPredict)
        #classifier
        self.classifier = LogisticRegression
        #how to process data
        self.ensembleFeatures()
    
    def log_reg(self):
        self.c = self.classifier(**self.ensemble_params)
        self.c.fit(self.fit_data, self.fit_labels)
        lor_pred = self.c.predict(self.predict_data)
        # Return the prediction matrix, coefficients
        return lor_pred
    
    def ensembleFeatures(self):
        '''
        creates self.fit_data, self.predict_data and self.feature_names
        '''
        ###TEXT FEATURES
        e1 = Baseline(self.dfFit,self.dfPredict,self.baseline_params)
        e1.run_model()
        print "Baseline has this many words: ",e1.fit_data.shape
        ###prune BaselineTuned features
        f1,p1,l1 = fe.reVectorizer(e1,n_keep = 6000)
        print "after pruning, we are left wth this many words: ",f1.shape
        l1 = l1.tolist()
        ###NUMERIC FEATURES
        f2,l2 = fe.augNumericFeatures(self.dfFit) 
        p2,_ = fe.augNumericFeatures(self.dfPredict)
        f2 = normalize(f2)
        p2 = normalize(p2)

        ###COMBINE
        print p1.toarray().shape
        print p2.shape
        
        self.fit_data = np.column_stack((f1.toarray(),f2))
        self.feature_names = l1+l2      
        self.predict_data = np.column_stack((p1.toarray(),p2))
        '''
        self.fit_data = f1
        self.feature_names = l1     
        self.predict_data = p1    
        '''

# %% [markdown]
# Unfortunately we overfit the pruning a little bit- The param tuning (found in Experiments section) would sometimes indicate scores of 0.57 and 0.58 but different splits (and submission to Kaggle) indicates the real score to be about 0.55.

# %%
b_params = {'min_df':0.01,'max_df':0.45} # Found by experimentation in Experiments cell
elr = LRMixed(master_data.getTrain(),master_data.getDev(),baseline_params=b_params)
elr.run_model()
print elr.test()
# Out:
# Baseline has this many words:  (3030, 765)
# after pruning, we are left wth this many words:  (3030, 765)
# (1010L, 765L)
# (1010L, 24L)
# 0.556860820417

# %%
#Run final
b_params = {'min_df':0.01,'max_df':0.45}
elr = EnsembleLR(master_data.getTrainFull(),master_data.getTest(),baseline_params=b_params)
elr.run_model()
elr.writeSubmission('ELR_pruned_submission.csv')
# Out:
# Baseline has this many words:  (4040, 766)
# after pruning, we are left wth this many words:  (4040, 766)
# (1631, 766)
# (1631, 21)
# [0 0 0 ..., 0 1 0]
# Written to File!

# %% [markdown]
# <a id="part5h"></a>
# ### h. Numeric GMM with PCA

# %% [markdown]
# Due to the large amount of numeric features that are possibly correlated, we tried PCA based on assignment 3. We were extremely surprised to find that this is our best model.
#
# The best feature set was to just use every avail numeric feature, not including the 10 topic modelling scores. Hypothesise that PCA is effective at not getting confused with messy or correlated features, but not sure why it didn't like Topic Modelling.
#
# Hyperparams for PCA and GMM tuned in Experiments section.

# %%
class PCAGMM(Model):
    '''
    PCA followed by GMM
    '''
    def __init__(self,dfFit,dfPredict,k=3,cov_type='spherical',n=6,**kwargs):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = GMM
        #hyperparams
        self.k = k #number of PCA dimensions
        self.cov_type = cov_type
        self.n = n #number of GMM components
        #how to process data
        f1,l1 = fe.augNumericFeatures(self.dfFit)
        p1,_ = fe.augNumericFeatures(self.dfPredict)

        self.feature_names = self.conductPCA(f1,p1)
        """
        #Ensemble
        elr = EnsembleLR(dfFit,dfFit)
        elr.run_model()
        f2 = elr.prediction
        
        elr2 = EnsembleLR(dfFit,dfPredict)
        elr2.run_model()
        p2 = elr2.prediction
        
        l2 = ['ELR prediction']
        
        #Combine
        f_c = np.column_stack((f1,f2))
        p_c = np.column_stack((p1,p2))
        self.feature_names = self.conductPCA(f_c,p_c) + l2
        """
    def run_model(self):
        #predict
        self.prediction = self.classify()    
    
    def calcNumberParams(self,k,cm_type,n):
        '''
        Calculates number of parameters in model
        '''
        if cm_type=='spherical':
            return (k+1)*n*2
        elif cm_type=='tied':
            return (k)*n*2 + (k**2)*1*2 #first term is for mean vector, second is for cov matrix
        elif cm_type=='diag':
            return (k+k)*n*2
        elif cm_type=='full':
            return (k+k**2)*n*2
        else:
            raise ValueError('Invalid covariance matrix type')
    
    def conductPCA(self,f,p):
        #firstly normalize
        f = normalize(f)
        p = normalize(p)
        
        #transform data
        pca = PCA(n_components=self.k)
        fit_data_dimk = pca.fit_transform(f)
        predict_data_dimk = pca.transform(p)
        
        #save as instance vars
        self.fit_data = fit_data_dimk
        self.predict_data = predict_data_dimk
        return ['No Name']*self.k

    def classify(self):
     
        #separate into positive and negative classification examples
        fit_data_positive = self.fit_data[self.fit_labels,:]
        fit_data_negative = self.fit_data[~self.fit_labels,:]
        
        #fit GMMs
        g_pos = GMM(n_components=self.n,covariance_type=self.cov_type)
        g_pos.fit(fit_data_positive)
        g_neg = GMM(n_components=self.n,covariance_type=self.cov_type)
        g_neg.fit(fit_data_negative)

        #predict
        p_pos = g_pos.score(self.predict_data)
        p_neg = g_neg.score(self.predict_data)
        return (p_pos>p_neg).astype(int)

# %%
pcagmm_model = PCAGMM(master_data.getTrain(),master_data.getDev())
pcagmm_model.run_model()
print pcagmm_model.test()
print "This is our best model, and it only uses numeric features!"
# Out:
# 0.590055359414
# This is our best model, and it only uses numeric features!

# %%
'''
Experiment: Try to prune PCAGMM features by Leaving One Out
This will help find a local optimum of features and possibly indicate what the most important features are.
'''
pcagmm_model = PCAGMM(master_data.getTrain(),master_data.getDev())
pcagmm_model.run_model()
print "AUC score of full feature set:"
print pcagmm_model.test()

#mung features
f1,l1 = fe.augNumericFeatures(pcagmm_model.dfFit)
p1,_ = fe.augNumericFeatures(pcagmm_model.dfPredict)

f2,l2 = fe.newTimeInfo(pcagmm_model.dfFit)
p2,_ = fe.newTimeInfo(pcagmm_model.dfPredict)

f_c = np.column_stack((f1,f2[:,2])) # only want one of the 3 features in f2
p_c = np.column_stack((p1,p2[:,2]))
l_c = l1 + l2[2:3]
n_features = len(l_c)
r = range(n_features)

#omit features permanently, based on iterations of this experiment:
f_c = f_c[:,r[:i] + r[i+1:n+1]]

remove_perm = [21,20,18]

for rem in remove_perm:
    f_trim = f_c[:,r[:rem] + r[rem+1:n+1]] #calc new ommitted feature vecs
    l_trim = l_c[:rem] + l_c[rem+1:n+1]
    p_trim = p_c[:,r[:rem] + r[rem+1:n+1]]

    f_c = f_trim #resave
    l_c = l_trim
    p_c = p_trim

n_features = len(l_c)
r = range(n_features)

print "AUC scores as a result of leaving out a feature:"

for i in range(n_features):
    #REMOVE DATA!!!!
    f_trim = f_c[:,r[:i] + r[i+1:n+1]]
    l_trim = l_c[:i] + l_c[i+1:n+1]
    p_trim = p_c[:,r[:i] + r[i+1:n+1]]
    
    #save
    pcagmm_model.feature_names = pcagmm_model.conductPCA(f_trim,p_trim)
    #run
    pcagmm_model.run_model()
    print pcagmm_model.test(), ' omitted i=',i,', ', l_c[i]
# Out:
# AUC score of full feature set:
# 0.590055359414
# AUC scores as a result of leaving out a feature:
# 0.568866794379  omitted i= 0 ,  title_length
# 0.582028508251  omitted i= 1 ,  req_length
# 0.49741145924  omitted i= 2 ,  avg_word_length
# 0.498725519687  omitted i= 3 ,  title_caps_norm
# 0.499419491369  omitted i= 4 ,  req_caps_norm
# 0.499419491369  omitted i= 5 ,  num_numbers_norm
# 0.498725519687  omitted i= 6 ,  num_currency_chars_norm
# 0.499419491369  omitted i= 7 ,  num_exclamation_norm
# 0.498725519687  omitted i= 8 ,  num_commas_norm
# 0.523893207521  omitted i= 9 ,  requester_account_age_in_days_at_request
# 0.495485226055  omitted i= 10 ,  requester_days_since_first_post_on_raop_at_request
# 0.498725519687  omitted i= 11 ,  requester_number_of_comments_at_request
# 0.556494044509  omitted i= 12 ,  requester_number_of_comments_in_raop_at_request
# 0.545058024476  omitted i= 13 ,  requester_number_of_posts_at_request
# 0.561824169213  omitted i= 14 ,  requester_number_of_posts_on_raop_at_request
# 0.561824169213  omitted i= 15 ,  requester_number_of_subreddits_at_request
# 0.543242615666  omitted i= 16 ,  requester_upvotes_minus_downvotes_at_request
# 0.5820232309  omitted i= 17 ,  requester_upvotes_plus_downvotes_at_request

# %%
'''
Run pruned PCAGMM model on Test set
Write to a csv for submission to Kaggle
'''
pcagmm_model = PCAGMM(master_data.getTrainFull(),master_data.getTest())

#mung features
f1,l1 = fe.augNumericFeatures(pcagmm_model.dfFit)
p1,_ = fe.augNumericFeatures(pcagmm_model.dfPredict)

f2,l2 = fe.newTimeInfo(pcagmm_model.dfFit)
p2,_ = fe.newTimeInfo(pcagmm_model.dfPredict)

f_c = np.column_stack((f1,f2[:,2])) # only want one of the 3 features in f2
p_c = np.column_stack((p1,p2[:,2]))
l_c = l1 + l2[2:3]
n_features = len(l_c)
r = range(n_features)

#omit features permanently, based on iterations of this experiment:
f_c = f_c[:,r[:i] + r[i+1:n+1]]

remove_perm = [21,20,18]

for rem in remove_perm:
    f_trim = f_c[:,r[:rem] + r[rem+1:n+1]] #calc new ommitted feature vecs
    l_trim = l_c[:rem] + l_c[rem+1:n+1]
    p_trim = p_c[:,r[:rem] + r[rem+1:n+1]]

    f_c = f_trim #resave
    l_c = l_trim
    p_c = p_trim

#save
pcagmm_model.feature_names = pcagmm_model.conductPCA(f_trim,p_trim)
#run
pcagmm_model.run_model()
#write to file
pcagmm_model.writeSubmission('PCAGMM_pruned.csv')
# Out:
# [1 1 0 ..., 1 1 1]
# Written to File!

# %% [markdown]
# <a id="part5i"></a>
# ### i. Ensemble GMM with PCA and Topic Modeling

# %%
'''
Try GMM only with topic deciles...
Note PCA is bypassed. Topics go straight into GMM!
'''

fit_deciles = fe.deciles(developmentTM.fit_topics)
predict_deciles = fe.deciles(developmentTM.predict_topics)
print type(fit_deciles)
p = PCAGMM(master_data.getTrain(),master_data.getDev())
p.fit_data = fit_deciles
p.predict_data = predict_deciles
p.run_model()
print p.test()

print "insane! 0.575 on topics (in deciles) and 0.59 on numeric features. However combining gives 0.56"
# Out:
# <type 'numpy.ndarray'>
# 0.561093256073
# insane! 0.575 on topics (in deciles) and 0.59 on numeric features. However combining gives 0.56

# %%
class PCAGMM_extended(PCAGMM):
    '''
    PCA followed by GMM
    Uses Topic Modelling data AND Numeric features
    -Topic selection was attempted but only made the model slightly worse 
    '''
    def __init__(self,dfFit,dfPredict,k=3,cov_type='spherical',n=6,**kwargs):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = GMM
        #hyperparams
        self.k = k #number of PCA dimensions
        self.cov_type = cov_type
        self.n = n #number of GMM components
        #how to process data
        f1,l1 = fe.augNumericFeatures(self.dfFit)
        p1,_ = fe.augNumericFeatures(self.dfPredict)
        #topic features
        f2 = fe.deciles(developmentTM.fit_topics) #use developmentTM at dev time, finalTM object at Test time
        p2 = fe.deciles(developmentTM.predict_topics)
        f_c = np.column_stack((f1,f2))
        p_c = np.column_stack((p1,p2))
    
        self.feature_names = self.conductPCA(f_c,p_c)

# %%
pcagmm_e_model = PCAGMM_extended(master_data.getTrain(),master_data.getDev())
pcagmm_e_model.run_model()
print pcagmm_e_model.test()
print "Performance does not improve..."
# Out:
# 0.588704357509
# Performance does not improve...

# %% [markdown]
# <a id="part5j"></a>
# ### j. Text Logistic Regression with Preprocessing

# %%
class Preproc(Model):
   
    '''
    Preprocessor

    Things I tried and kept
    -remove apostrophes
    -remove punctuation
    -remove white space
    -stem words
    -keep only words that turn up in a US english dictionary

    Things I tried and removed
    -remove stop words (both custom and default english)
    -make all lowercase
    -try to correct misspelled words
    -rearranging steps in the preprocessor
    -lots of other types of stemmers
    
    Things I tried that failed, but I left some code and never
    -SVM instead of logistic regression
    -TF-IDF transformation
    '''
    
    def __init__(self,dfFit,dfPredict):
        Model.__init__(self,dfFit,dfPredict)
        #Mull over some options here
        #self.classifier = SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=5, random_state=42)
        self.classifier = LogisticRegression
        self.c = self.classifier(penalty='l2')
        #how to process data
        raw_fit = self.dfFit['request_text_edit_aware'].values
        raw_predict = self.dfPredict['request_text_edit_aware'].values
        self.fit_data, self.predict_data = self.vectorize(raw_fit,raw_predict,self.better_preprocessor_matt)

    def run_model(self):
        self.prediction = self.log_reg()
        
    def better_preprocessor_mike(self,s):
        #remove plurals "es,s,ies" and other suffixes
        s = re.sub(r'(?<=\w)ies(?=\W|$)','y',s)
        #s = re.sub(r'(?<=\w)(?:es|ing|ly)(?=\W|$)','',s) #removes es,ing,ly
        #s = re.sub(r'(?<=\w)(?:es)(?=\W|$)','',s)
        s = re.sub(r'(?<=[bcdfghjklmnpqrtuvwxyz])(?:s|ed)(?=\W|$)','',s) #drop 's' or 'ed' if preceded by a consonant
        #remove any non letters, numbers, a few intersting chars, and whitespace
        #s = re.sub(r'[^\w\s,.!@$%]+','',s)
        #remove part of email addresses, keeping domain only
        #s = re.sub(r'(?<=\s)[a-zA-Z_.0-9]+@','@',s)
        #replace numbers with a single token
        #s = re.sub(r'[0-9]+','1',s)
        #delete mixed words/numbers
        #s = re.sub(r'(?<=\s)(?:\d+[a-zA-Z]+\w*|[a-zA-Z]+\d+\w*)(?=\W|$)','',s)
        #lowercase everything
        s = s.lower()
        #Delete everything except alpha and separators!
        #s = re.sub(r'[^a-zA-Z,\s\.]+','',s)
        return s
    
    def better_preprocessor_matt(self,s):
        st = PorterStemmer()
        #chkr = enchant.checker.SpellChecker("en_US")
        #print s
        #s = strip_accents_unicode(s).lower() #make everything lowercase
        s = re.sub('[?,-/><=+_!.:()]',' ',s) #turn a lot of punctuations into spaces
        s = ' '.join(s.split()) #remove excess white space
        #s = " ".join(word for word in s.split() if chkr.check(word) == True) #remove incorrectly spelled words
        s = " ".join(st.stem(word) for word in s.split(" "))
        s = re.sub('[\']','',s) #remove apostrophes
        #print s
        return s
        
    def vectorize(self,raw_fit,raw_predict,prepro):
        # transform the train data
        vectorizer_train = CountVectorizer(preprocessor=prepro,stop_words = ['pizza', 'pizzas', 'request', 'requests'])
        fit_data = vectorizer_train.fit_transform(raw_fit)
        #########################tfidf_transformer = TfidfTransformer()
        #########################fit_data_tfidf = tfidf_transformer.fit_transform(fit_data)

        # transform the dev data using the same vocab
        predict_data = vectorizer_train.transform(raw_predict)     # 'transform' function will preserve previous vocab
        ###########################predict_data_tfidf = tfidf_transformer.transform(predict_data)
        
        return fit_data, predict_data
        #return fit_data_tfidf, predict_data_tfidf

    def log_reg(self):
        self.c.fit(self.fit_data, self.fit_labels)
        lor_pred = self.c.predict(self.predict_data)
        # Return the prediction matrix, coefficients
        return lor_pred

# %% [raw]
# Note: In the preprocessor, #chkr = enchant.checker.SpellChecker("en_US") and #s = ..... #remove incorrectly spelled words lines are commented out because I can't install enchant. This checks spelling and adds a rather nice 1.5 point performance boost.

# %%
preproc_model = Preproc(master_data.getTrain(),master_data.getDev())
preproc_model.run_model()
print preproc_model.test()
# Out:
# 0.552918639077

# %% [markdown]
# <a id="part5k"></a>
# ### k. Mixed Text, Topic and Numeric Logistic Regression with Preprocessing

# %%
class MixedPreproc(Preproc):
    '''
    This is the "Everything" model
    Take previous LR with preprocessing and add in other data.
    '''
   
    def __init__(self,dfFit,dfPredict):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = LogisticRegression(penalty='l2',C=2)
        #how to process data
        raw_fit = self.dfFit['request_text_edit_aware'].values
        raw_predict = self.dfPredict['request_text_edit_aware'].values
        #text features
        f1,p1,l1 = fe.vectorize(raw_fit,raw_predict,params={'preprocessor':self.better_preprocessor_matt,
                                                          'min_df':0.01,
                                                          'max_df':0.5})
        #topic features
        f2 = fe.deciles(developmentTM.fit_topics) #use developmentTM at dev time, finalTM object at Test time
        p2 = fe.deciles(developmentTM.predict_topics)
        #numeric features
        f3,_ = fe.augNumericFeatures(self.dfFit)
        p3,_ = fe.augNumericFeatures(self.dfPredict)

        #merge
        f_c = np.column_stack((f1.toarray(),f2,f3))
        p_c = np.column_stack((p1.toarray(),p2,p3))

        self.fit_data = f_c
        self.predict_data = p_c

    def better_preprocessor_matt(self,s):
        '''
        Had to remove enchant checker because I can't install it. Feel free to uncomment - Mike
        '''
        st = PorterStemmer()
        #chkr = enchant.checker.SpellChecker("en_US")
        #print s
        #s = strip_accents_unicode(s).lower() #make everything lowercase
        s = re.sub('[?,-/><=+_!.:()]',' ',s) #turn a lot of punctuations into spaces
        s = ' '.join(s.split()) #remove excess white space
        #s = " ".join(word for word in s.split() if chkr.check(word) == True) #remove incorrectly spelled words
        s = " ".join(st.stem(word) for word in s.split(" "))
        s = re.sub('[\']','',s) #remove apostrophes
        #print s
        return s

# %%
preproc_model = MixedPreproc(master_data.getTrain(),master_data.getDev())
preproc_model.run_model()
print preproc_model.test()
print "Note the result of 0.558 doesn't include the spell checker."
# Out:
# 0.558285705239
# Note the result of 0.558 doesn't include the spell checker.

# %% [markdown]
# <a id="part6"></a>
# ## 6. Experiments

# %%
"""
EXPERIMENTS Cell
Cell for all experiments that don't fit neatly elsewhere.
"""

def tuneBaseline():
    '''
    Conducts a GridSearch of LR params
    Visualizes result - useful to discern if result is from overfitting or not
    WARNING: Takes several minutes!
    '''

    #initiate a Baseline obj
    baseline_model = Baseline(master_data.getTrain(),master_data.getDev())

    ####Run grid search
    params = {'penalty': ['l1','l2'],'C':np.logspace(-2,2,30)}
    gs = baseline_model.gridSearch(params)

    ####Print and plot results
    scores = gs.grid_scores_

    l1_means = []
    l2_means = []
    C = []

    for i in range(len(gs.grid_scores_)):
        #append to relevant means vector
        if scores[i][0]['penalty'] == 'l1':
            l1_means.append(scores[i][1])
            #append C vector
            C.append(scores[i][0]['C'])
        elif scores[i][0]['penalty'] == 'l2':
            l2_means.append(scores[i][1])
        else:
            raise ValueError("function can't handle given params")

    #plot   
    plt.plot(C,l1_means,C,l2_means,'r')
    #plt.plot()
    plt.semilogx()
    plt.legend(['l1 penalty','l2 penalty'],'best')
    plt.show()

def compareTunedBaseline():
    '''
    This cell demonstrates Cross Val and GridSearch coming up with optimistic results and unhelpful params
    '''

    # Run test of baseline
    baseline_model = Baseline(master_data.getTrain(),master_data.getDev())
    baseline_model.run_model()
    print baseline_model.test()
    #featureImportanceVisualizer(baseline_model) 

    # Run test of BaselineTuned
    tuned = BaselineTuned(master_data.getTrain(),master_data.getDev())
    tuned.run_model()
    print 'test result: ', tuned.test()

    crossVal = tuned.crossVal({'penalty': 'l1', 'C': 0.092})
    print 'Cross Val is being overly optimistic again!'
    #featureImportanceVisualizer(tuned) 

def printWorstPredictions(fitted_model,n=5):
    '''
    Prints the most wrong predictions, hopefully for some insight!
    requires a fitted model that can predict a probability. 
    Ensure classifier is stored as an instance variable self.c in the model class
    '''
    
    #collect documents R = max predicted prob / predicted prob of correct label
    R = []
    for i in range(fitted_model.predict_data.shape[0]):
        probs = fitted_model.c.predict_proba(fitted_model.predict_data[i,:])[0]
        R.append(float(max(probs))/probs[fitted_model.dfPredict['requester_received_pizza'].values[i]])
    top = np.argsort(R)[-n:] 

    #print results
    for i in top: #for the first n examples in training data
        #print data and labels
        print '\n...Document #%i...' %(i)
        print 'True Label: %s' %fitted_model.dfPredict['requester_received_pizza'].values[i]
        print 'Predicted Label: %s' %fitted_model.prediction[i]
        print 'Data:\n"%s"' %fe.unionText(fitted_model.dfPredict)[i],'\n'
        print 'Metadata:'
        f,l = fe.augNumericFeatures(fitted_model.dfPredict)
        for j in range(len(l)):
            print 'label: ',l[j],', val: ',f[i,j]
            
def tuneEnsembleTree():
    '''
    Conducts a GridSearch of DT params
    Visualizes result - useful to discern if result is from overfitting or not
    WARNING: Takes several minutes!
    '''

    #initiate a ET obj
    et_model = EnsembleTree(master_data.getTrain(),master_data.getDev())

    ####Run grid search
    params = {'max_depth':range(2,7),'criterion':['gini','entropy']}
    gs = et_model.gridSearch(params)

    ####Print and plot results
    scores = gs.grid_scores_
    pprint(scores)
    gini_means = []
    entropy_means = []
    max_depth = []

    for i in range(len(gs.grid_scores_)):
        #append to relevant means vector
        if scores[i][0]['criterion'] == 'gini':
            gini_means.append(scores[i][1])
            #append max_depth vector
            max_depth.append(scores[i][0]['max_depth'])
        elif scores[i][0]['criterion'] == 'entropy':
            entropy_means.append(scores[i][1])
        else:
            raise ValueError("function can't handle given params")

    #plot   
    plt.plot(max_depth,gini_means,max_depth,entropy_means,'r')
    #plt.plot()
    #plt.semilogx()
    plt.legend(['gini','entropy'],'best')
    plt.show()

def trimWords():
    '''
    Trim infrequent and frequent words before any analysis goes down
    '''
    for mindf in np.linspace(0.0,0.05,6):
        for maxdf in np.linspace(0.4,0.6,6):
            params = {'min_df':mindf,'max_df':maxdf}
            baseline_model = Baseline(master_data.getTrain(),master_data.getDev(),params)
            baseline_model.run_model()
            print baseline_model.test(),' ',params,
            print 'Words in model: ',baseline_model.fit_data.shape[1]
    
def pruneWords(params):
    '''
    Prune the less-importance features and test resulting performance
    '''
    results = []

    baseline_model = Baseline(master_data.getTrain(),master_data.getDev(),params)
    baseline_model.run_model()
    c = baseline_model.c
    importances = c.coef_[0,:]
    old_names = baseline_model.feature_names
    old_fit_data = baseline_model.fit_data
    old_predict_data = baseline_model.predict_data

    for i in np.linspace(20,old_fit_data.shape[1],41):

        n=i        
        ind = np.argsort(-np.absolute(importances))[:n]
        newVocab = np.asarray(old_names)[ind]

        fit_new = old_fit_data[:,ind]
        predict_new = old_predict_data[:,ind]

        baseline_model.fit_data = fit_new
        baseline_model.predict_data = predict_new

        baseline_model.run_model()
        results.append(baseline_model.test())
        print 'i =', i

    plt.plot(np.linspace(20,old_fit_data.shape[1],41),results)
    plt.xlabel('N words kept')
    plt.title('LR performance pruning all but N most important words')
    
    plt.show()
    
    
def tune_rf():
    #RF for cross val and GS purposes
    rf_model = RandomForestModel(master_data.getTrain(),master_data.getDev())

    #Run grid search

    params = {'n_estimators' : range(10,200,10),'criterion':['entropy']}
    gs = rf_model.gridSearch(params)

    #params = {'max_leaf_nodes' : [8,16,32,64,128,256,512,1024,2048],'n_estimators':[50],'criterion':['entropy']}
    #gs = rf_model.gridSearch(params)

    pprint(gs.grid_scores_)

    #now cross val on best GS values
    rf_model.crossVal({'n_estimators': 150, 'criterion': 'entropy'})

    print "Clearly these results are overly optimistic..."

def compareLR():
    '''
    Compare LR vs EnsembleLR
    THe difference is: incorporation of augNumericFeatures AND text 
    '''
    blr = Baseline(master_data.getTrain(),master_data.getDev())
    blr.run_model()
    print blr.test()

    elr = EnsembleLR(master_data.getTrain(),master_data.getDev())
    elr.run_model()
    print elr.test()

def normalizeData():
    '''
    See what happens when data is normalized with normalize()
    Only for numeric data!
    Try models: NumericModel and PCAGMM
    
    Hint: I've already tried this and it improves an LR by about 0.5
    '''
    raise NotImplementedError

def compareRF():
    '''
    What happens when we add the output of a LR into an RF model?
    '''
    #Run test of random forest
    rf_model = RandomForestModel(master_data.getTrain(),master_data.getDev())
    rf_model.run_model()
    print "RF performance: ",rf_model.test()

    #Run test of EnsembleForest
    ef_model = EnsembleForest(master_data.getTrain(),master_data.getDev())
    ef_model.run_model()
    print "EF performance (added lvl1 classifier): ",ef_model.test()

    #Run feature importance vis using random forest
    featureImportanceVisualizer(ef_model)
    print ("""This seems to be a failure in entropy analysis to select important features. 
           The model ranks lvl1classifier very low even though it's standalone performance is better than the RF""")

def tunePCAGMM(max_params=50):
    
    def calcNumberParams(k,cov_type,n):
        '''
        Calculates number of parameters in model
        '''
        if c=='spherical':
            return (k+1)*n*2
        elif c=='tied':
            return (k)*n*2 + (k**2)*1*2 #first term is for mean vector, second is for cov matrix
        elif c=='diag':
            return (k+k)*n*2
        elif c=='full':
            return (k+k**2)*n*2
        else:
            raise ValueError('Invalid covariance matrix type')

    #compute/create variables
    results = [[],[]]

    #initiate params to iterate through
    k_list = range(2,20,3) #number of PCA dimensions
    cov_types = ['spherical','tied','diag', 'full']
    n_list = range(1,15,3)
    
    t0 = time.time()
    print "Begin calculations\n"
    
    #iterate through PCA dimensions up to 50
    for k in k_list:
        #iterate through covariance type
        for c in cov_types:
            #iterate through GMM components
            for n in n_list:
                #break loop if number of params is too high, 
                #thereby skipping to another covariance type.
                if calcNumberParams(k,c,n) > max_params:
                    break
                else:         
                    #Run test on PCAGMM model
                    params = {'k':k,'cov_type':c,'n':n}
                    pcagmm_model = PCAGMM(master_data.getTrain(),master_data.getDev(),**params)
                    pcagmm_model.run_model()
                    score = pcagmm_model.test()
                    results[0].append(score)
                    results[1].append(params)
                    print results[1][-1],' calculation complete, score= ',results[0][-1]
    print "\nAll calculations complete, time elapsed= %3.3f seconds" % (time.time()-t0)
    
    #Extract best model:
    max_value = max(results[0])
    max_index = results[0].index(max_value)
    best_params = results[1][max_index]
    print "\nBest Model"
    print "accuracy= ",max_value
    print "(PCA dimensions,covariance_type,GMM components)= ",best_params
    print "Number of parameters used= ",calcNumberParams(**best_params)

    ### EXTRACT 10 BEST MODELS FOR FUN:
    np_scores = np.asarray(results[0])
    np_params = np.asarray(results[1])
    max_indices = np.argsort(-np_scores)[:10]
    max_scores = np_scores[max_indices]
    best_params = np_params[max_indices]
    print "10 best models"
    for i in range(max_scores.shape[0]):
        print "Accuracy [PCA dim, covar type, GMM components]: ",max_scores[i], best_params[i]
    
    return results

def examineAugFeatures():
    data,feature_names = fe.augNumericFeatures(master_data.getTrain())
    labels = master_data.getTrain()['requester_received_pizza'].values.astype(bool)
    visFeatures(data,feature_names,labels)
    '''
    FROM SCATTER:
    The visualization isn't useful for many of the numeric features, but is good for some
    Clearly we have some data quality issues with some features:
    -extreme outliers on avg_word_length,req_caps_norm,num_currency_chars_norm,and the 2 karma metrics.
    None of the features seem super obvious- effect sizes are small.
    
    FROM HISTOGRAM:
    Suggested encoding of features:
    title_length: continuous
    req_length: continuous
    num_commas_norm: Binary (>0.0025)
    requester_account_age_in_days_at_request: Binary (>7)
    requester_days_since_first_post_on_raop_at_request: Binary (>10)
    requester_number_of_comments_in_raop_at_request: Binary (>1)
    requester_number_of_posts_on_raop_at_request: Binary (>0)
    day_of_month: Binary (>15)
    hour: Binary (>5)
    '''

def nounsPerformance():
    '''
    Experiment: Reduce corpus to nouns and compare Logistic Regression performance.
    '''
    dfTrain = master_data.getTrain()
    dfDev = master_data.getDev()
    b_nouns = Baseline(dfTrain,dfDev)
    b_nouns.fit_data, b_nouns.predict_data, b_nouns.feature_names = fe.vectorize(fe.extractNouns(dfTrain),
                                                                                 fe.extractNouns(dfDev))
    b_nouns.run_model()
    print "Performance with just nouns: ", b_nouns.test()

    b_norm = Baseline(master_data.getTrain(),master_data.getDev())
    b_norm.run_model()
    print "Performance using full text: ", b_norm.test()

    print "Vocab reduced from %i words to %i words" % (b_norm.fit_data.shape[1],b_nouns.fit_data.shape[1])

# %%
tuneBaseline()
compareTunedBaseline()
# Out:
# {'penalty': 'l1', 'C': 0.067233575364993345}
# C:\Anaconda\lib\site-packages\matplotlib\cbook.py:133: MatplotlibDeprecationWarning: The "loc" positional argument to legend is deprecated. Please use the "loc" keyword instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# 0.529516225216
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-303-fdfb39d330c7> in <module>()
#       1 tuneBaseline()
# ----> 2 compareTunedBaseline()
#
# <ipython-input-302-fad17d691ac2> in compareTunedBaseline()
#      55
#      56     # Run test of BaselineTuned
# ---> 57     tuned = BaselineTuned(master_data.getTrain(),master_data.getDev())
#      58     tuned.run_model()
#      59     print 'test result: ', tuned.test()
#
# NameError: global name 'BaselineTuned' is not defined

# %%
printWorstPredictions(baseline_model,n=3)
# Out:
# ...Document #356...
# True Label: True
# Predicted Label: False
# Data:
# "[REQUEST] (Washington, DC) GF and I are broke, I'm cut off b/c I'm depressed, worked 12 hours between 2 jobs today, exhausted and starving. (xpost the other raop) I was cut off by my parents a couple months ago because I've been fighting depression and they didn't like my behavior. Since then I've been struggling to finish school while blowing through my savings because of my nasty eating habit till they ran out at the end of the school year and have been living off the generosity of my gf since I picked up 2 jobs and worked 12 hours today but I haven't worked long enough to be paid. We're both broke and hungry and neither of us have eaten today (it's 9:30 here) and I need food so I can work more tomorrow!!! Once I have paychecks coming in I'll pay it forward. Thank you!!"
#
# Metadata:
# label:  title_length , val:  162.0
# label:  req_length , val:  619.0
# label:  avg_word_length , val:  5.20168067227
# label:  title_caps_norm , val:  0.0920245398773
# label:  req_caps_norm , val:  0.0209677419355
# label:  num_numbers_norm , val:  0.00967741935484
# label:  num_currency_chars_norm , val:  0.0
# label:  num_exclamation_norm , val:  0.00806451612903
# label:  num_commas_norm , val:  0.0
# label:  requester_account_age_in_days_at_request , val:  158.327418981
# label:  requester_days_since_first_post_on_raop_at_request , val:  0.0
# label:  requester_number_of_comments_at_request , val:  152.0
# label:  requester_number_of_comments_in_raop_at_request , val:  0.0
# label:  requester_number_of_posts_at_request , val:  20.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  26.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  1789.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  3169.0
# label:  month , val:  5.0
# label:  day_of_month , val:  23.0
# label:  hour , val:  11.0
#
# ...Document #71...
# True Label: True
# Predicted Label: False
# Data:
# "[REQUEST] Working woman with an asshole roommate could use a pizza. Not sure if this is the purpose of this reddit. Please excuse the new account, I saw this on the news, what an amazing idea!
#
# I am currently living with a roommate who has just moved out of her mother's house, she has no job and her mother sends her utility and rent money. Her only responsibility is to send her mom the rent bill, and she sends half of that or pays half to the company. The problem is that this girl is SO lazy, can't be bothered to send the bills, can't be bothered to call her mom for rent and I'm under the impression she told her mom she already had a job (her mom has been chiding her for not having a job), so her mother does not feel obligated to pay this girl's bills. I have been carrying the weight of the major bills, such as electricity and rent (2x), and my paycheck is being stretched thin. To top it off, it's obvious to see where she gets her flaky attitude from...her mother REFUSES to answer my phone calls or emails. So here I am reddit, living with a girl who labels her food in the fridge so I don't touch it, and for the sake of keeping the peace...I am down to begging for a pizza X(.  I would prefer giftcards, because I would rather give out my email address than my physical address, but I will understand those who dont want to in case they believe I am a scammer.
#
#
# My email address is: Jen.Beam.1984@gmail.com"
#
# Metadata:
# label:  title_length , val:  67.0
# label:  req_length , val:  1356.0
# label:  avg_word_length , val:  5.19540229885
# label:  title_caps_norm , val:  0.117647058824
# label:  req_caps_norm , val:  0.0221075902727
# label:  num_numbers_norm , val:  0.00368459837878
# label:  num_currency_chars_norm , val:  0.0
# label:  num_exclamation_norm , val:  0.000736919675755
# label:  num_commas_norm , val:  0.0103168754606
# label:  requester_account_age_in_days_at_request , val:  0.0
# label:  requester_days_since_first_post_on_raop_at_request , val:  0.0
# label:  requester_number_of_comments_at_request , val:  0.0
# label:  requester_number_of_comments_in_raop_at_request , val:  0.0
# label:  requester_number_of_posts_at_request , val:  0.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  0.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  0.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  0.0
# label:  month , val:  7.0
# label:  day_of_month , val:  11.0
# label:  hour , val:  8.0
#
# ...Document #171...
# True Label: False
# Predicted Label: True
# Data:
# "(request) Been up all night crying, screaming, and now starving. Jacksonville FL. I'm not new to Reddit and I'm not from Jacksonville either. Sorry but I'm requesting incognito because I don't want anyone I know to find out about what's happening right now. There's a really messed up situation and I haven't even told my dad about this yet, so I don't want my friends or cousins finding out yet either because they can't keep their mouths shut.
#
# I got a surprise yesterday when a guy I've never even met greets me in the hallway of my apartment building and tells me he wants me to leave my girlfriend of 2 years. My girlfriend then confronts us both and gives me the shock of my life, she's been cheating on me with this guy, and she's pregnant, but she's 90% certain neither of us is the father! She was cheating on me with this guy, and cheating on him with someone else. I've never raised a hand to a girl and never will, I was raised better than that, but I've never been more tempted in my life to haul back and deck someone!
#
# After a two hour conversation with this dude I find out she hasn't been working for a whole year. He's been paying our electric and water since we moved into the apartment! She goes over to his house almost daily when she left me to head to work. Some days she leaves and neither of us could account for where she was. My girlfriend of 2 years is a lady of the night and has been milking 3 guys, me included and maybe more than just us, for everything we've got for years!
#
# I'm at my bros house and he's been very tolerant of all this, real step up kind of guy to take me in because I've been living with this tramp for over a year now, I got no place else to go right now. I need something to eat because neither of us has any money and he's living off noodles right now. I'll happily pay it forward on the 8th when I get paid. But for today, I need something better than noodles or black beans and rice, and I think he would appreciate it too.
#
# Sorry again for being a bit deceptive with my post. If I wasn't starving I wouldn't be spreading it around for that matter either. If anyone can help you have my gratitude.
#
# 8:30 AM. Taking a trip out and about, will be back in a few hours to check the thread.
# "
#
# Metadata:
# label:  title_length , val:  81.0
# label:  req_length , val:  2161.0
# label:  avg_word_length , val:  5.15751789976
# label:  title_caps_norm , val:  0.0487804878049
# label:  req_caps_norm , val:  0.0189639222942
# label:  num_numbers_norm , val:  0.00416281221092
# label:  num_currency_chars_norm , val:  0.0
# label:  num_exclamation_norm , val:  0.00185013876041
# label:  num_commas_norm , val:  0.00647548566142
# label:  requester_account_age_in_days_at_request , val:  0.0
# label:  requester_days_since_first_post_on_raop_at_request , val:  0.0
# label:  requester_number_of_comments_at_request , val:  0.0
# label:  requester_number_of_comments_in_raop_at_request , val:  0.0
# label:  requester_number_of_posts_at_request , val:  0.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  0.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  0.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  0.0
# label:  month , val:  10.0
# label:  day_of_month , val:  30.0
# label:  hour , val:  21.0

# %% [markdown]
# Cross val and Grid search are great at giving tantalizing results that don't materialize. We found the below optimas weren't even good params.

# %%
tuneEnsembleTree()
# Out:
# {'criterion': 'entropy', 'max_depth': 5}
# [mean: 0.58056, std: 0.01178, params: {'criterion': 'gini', 'max_depth': 2},
#  mean: 0.58138, std: 0.02570, params: {'criterion': 'gini', 'max_depth': 3},
#  mean: 0.58076, std: 0.01807, params: {'criterion': 'gini', 'max_depth': 4},
#  mean: 0.58705, std: 0.02782, params: {'criterion': 'gini', 'max_depth': 5},
#  mean: 0.57898, std: 0.02319, params: {'criterion': 'gini', 'max_depth': 6},
#  mean: 0.56810, std: 0.00180, params: {'criterion': 'entropy', 'max_depth': 2},
#  mean: 0.57497, std: 0.01824, params: {'criterion': 'entropy', 'max_depth': 3},
#  mean: 0.60705, std: 0.01338, params: {'criterion': 'entropy', 'max_depth': 4},
#  mean: 0.61963, std: 0.01448, params: {'criterion': 'entropy', 'max_depth': 5},
#  mean: 0.60138, std: 0.03276, params: {'criterion': 'entropy', 'max_depth': 6}]

# %% [raw]
# As mentioned earlier, I thought it would be interesting to extracte feature importances as ranked by RFs.
#
# The below includes "lvl1classifier" which is the binary output of a LogisticRegression. Sometimes the RF would rate it highly (and score almost exactly the same), and sometimes it would rate it low and get a bad AUC score.
#
# This turned out to be a shaky way to do feature selection for other models- LogisticRegression suffered when we built subsets of these features informed by RandomForests.

# %%
compareRF()
# Out:
# RF performance:  0.519571056895
# EF performance (added lvl1 classifier):  0.550947548407
# This seems to be a failure in entropy analysis to select important features.
#            The model ranks lvl1classifier very low even though it's standalone performance is better than the RF

# %% [markdown]
# Below: Note the patch of 0.56 AUC. Probably overfitting.

# %%
trimWords()
# Out:
# 0.535503380143   {'max_df': 0.40000000000000002, 'min_df': 0.0} Words in model:  11529
# 0.540870446306   {'max_df': 0.44, 'min_df': 0.0} Words in model:  11532
# 0.536891323507   {'max_df': 0.47999999999999998, 'min_df': 0.0} Words in model:  11534
# 0.536891323507   {'max_df': 0.52000000000000002, 'min_df': 0.0} Words in model:  11534
# 0.536891323507   {'max_df': 0.56000000000000005, 'min_df': 0.0} Words in model:  11537
# 0.536891323507   {'max_df': 0.59999999999999998, 'min_df': 0.0} Words in model:  11537
# 0.549522663585   {'max_df': 0.40000000000000002, 'min_df': 0.01} Words in model:  761
# 0.546894542691   {'max_df': 0.44, 'min_df': 0.01} Words in model:  764
# 0.543535508657   {'max_df': 0.47999999999999998, 'min_df': 0.01} Words in model:  766
# 0.543535508657   {'max_df': 0.52000000000000002, 'min_df': 0.01} Words in model:  766
# 0.548939516278   {'max_df': 0.56000000000000005, 'min_df': 0.01} Words in model:  769
# 0.548939516278   {'max_df': 0.59999999999999998, 'min_df': 0.01} Words in model:  769
# 0.559998205701   {'max_df': 0.40000000000000002, 'min_df': 0.02} Words in model:  469
# 0.564671300181   {'max_df': 0.44, 'min_df': 0.02} Words in model:  472
# 0.565985360628   {'max_df': 0.47999999999999998, 'min_df': 0.02} Words in model:  474
# 0.565985360628   {'max_df': 0.52000000000000002, 'min_df': 0.02} Words in model:  474
# 0.561349207606   {'max_df': 0.56000000000000005, 'min_df': 0.02} Words in model:  477
# 0.561349207606   {'max_df': 0.59999999999999998, 'min_df': 0.02} Words in model:  477
# 0.530933194011   {'max_df': 0.40000000000000002, 'min_df': 0.029999999999999999} Words in model:  336
# 0.534366110962   {'max_df': 0.44, 'min_df': 0.029999999999999999} Words in model:  339
# 0.53637414309   {'max_df': 0.47999999999999998, 'min_df': 0.029999999999999999} Words in model:  341
# 0.53637414309   {'max_df': 0.52000000000000002, 'min_df': 0.029999999999999999} Words in model:  341
# 0.533052050515   {'max_df': 0.56000000000000005, 'min_df': 0.029999999999999999} Words in model:  344
# 0.533052050515   {'max_df': 0.59999999999999998, 'min_df': 0.029999999999999999} Words in model:  344
# 0.540020792764   {'max_df': 0.40000000000000002, 'min_df': 0.040000000000000001} Words in model:  254
# 0.544036857021   {'max_df': 0.44, 'min_df': 0.040000000000000001} Words in model:  257
# 0.546044889149   {'max_df': 0.47999999999999998, 'min_df': 0.040000000000000001} Words in model:  259
# 0.546044889149   {'max_df': 0.52000000000000002, 'min_df': 0.040000000000000001} Words in model:  259
# 0.545387858926   {'max_df': 0.56000000000000005, 'min_df': 0.040000000000000001} Words in model:  262
# 0.545387858926   {'max_df': 0.59999999999999998, 'min_df': 0.040000000000000001} Words in model:  262
# 0.528481864383   {'max_df': 0.40000000000000002, 'min_df': 0.050000000000000003} Words in model:  213
# 0.530526837969   {'max_df': 0.44, 'min_df': 0.050000000000000003} Words in model:  216
# 0.529869807746   {'max_df': 0.47999999999999998, 'min_df': 0.050000000000000003} Words in model:  218
# 0.529869807746   {'max_df': 0.52000000000000002, 'min_df': 0.050000000000000003} Words in model:  218
# 0.534579843685   {'max_df': 0.56000000000000005, 'min_df': 0.050000000000000003} Words in model:  221
# 0.534579843685   {'max_df': 0.59999999999999998, 'min_df': 0.050000000000000003} Words in model:  221

# %%
params = {'min_df':0.01,'max_df':0.50}
pruneWords(params)
# Out:
# i = 20.0
# i = 38.65
# i = 57.3
# i = 75.95
# i = 94.6
# i = 113.25
# i = 131.9
# i = 150.55
# i = 169.2
# i = 187.85
# i = 206.5
# i = 225.15
# i = 243.8
# i = 262.45
# i = 281.1
# i = 299.75
# i = 318.4
# i = 337.05
# i = 355.7
# i = 374.35
# i = 393.0
# i = 411.65
# i = 430.3
# i = 448.95
# i = 467.6
# i = 486.25
# i = 504.9
# i = 523.55
# i = 542.2
# i = 560.85
# i = 579.5
# i = 598.15
# i = 616.8
# i = 635.45
# i = 654.1
# i = 672.75
# i = 691.4
# i = 710.05
# i = 728.7
# i = 747.35
# i = 766.0

# %% [markdown]
# Below: LR performance with/without noun filtering (using NLTK). Only improper nouns were used. Notice the vocab much smaller for slightly less performance - probably less prone to overfitting.
#
# We found that topic modelling in particular worked much better after filtering non-nouns.

# %%
nounsPerformance()
# Out:
# all done in:  204.434000015
# all done in:  65.620000124
# Performance with just nouns:  0.524510657611
# Performance using full text:  0.529516225216
# Vocab reduced from 5929 words to 11546 words

# %%
colNamePrint()
# Out:
# 0 _ giver_username_if_known
# 1 _ request_id
# 2 _ request_text_edit_aware
# 3 _ request_title
# 4 _ requester_account_age_in_days_at_request
# 5 _ requester_days_since_first_post_on_raop_at_request
# 6 _ requester_number_of_comments_at_request
# 7 _ requester_number_of_comments_in_raop_at_request
# 8 _ requester_number_of_posts_at_request
# 9 _ requester_number_of_posts_on_raop_at_request
# 10 _ requester_number_of_subreddits_at_request
# 11 _ requester_subreddits_at_request
# 12 _ requester_upvotes_minus_downvotes_at_request
# 13 _ requester_upvotes_plus_downvotes_at_request
# 14 _ requester_username
# 15 _ unix_timestamp_of_request
# 16 _ unix_timestamp_of_request_utc

# %%
'''
TUTORIAL: This cell shows how the dataframes above get accessed and turned into usable numpy arrays
'''

###Task: Extracting message text AND title text into a feature vector:
#first find name of column by printing out the list of names
trainColumnNames = master_data.getTrainColumnNames()
pprint(trainColumnNames) #looks like we want 'request_text_edit_aware' and 'request_title'
#find which number this is or manually type column name
print '\n'
print trainColumnNames[7]
print trainColumnNames[8]

#two ways to get data we want:
print '\n'
X_train = master_data.getTrain()[['request_text_edit_aware','request_title']] #method 1
X_train = master_data.getTrain()[[trainColumnNames[7],trainColumnNames[8]]] #method 2
print X_train.head() #.head() just prints the first 5 rows

#The above X_train is still a pandas dataframe. Converting to numpy array for sklearn is as simple as:
print '\n'
X_train = X_train.values
print type(X_train)
print X_train.shape

#In summary (quick way):
X_train = master_data.getTrain()[['request_text_edit_aware','request_title']].values 

###Task: Join 2 numpy arrays horizontally (e.g. merge train and dev for final submission)
train_data = master_data.getTrain()['request_text_edit_aware'].values
dev_data = master_data.getDev()['request_text_edit_aware'].values
merged_data = np.concatenate((train_data,dev_data),axis=0)
print '\n'
print train_data.shape,' ',dev_data.shape,' ',merged_data.shape

###Task: Join 2 numpy arrays vertically (e.g. add a bunch of features)
train_data1 = master_data.getTrain()['request_text_edit_aware'].values
#now we want more features... say from some feature engineering process
train_data2 = master_data.getTrain()['request_title'].values
train_data_merged = np.column_stack((train_data1,train_data2)) #<---- where the action is at!
print '\n'
print train_data1.shape,' ',train_data2.shape,' ',train_data_merged.shape

###Task: Use the Classes
'''
To use:
1) instantiate your model class
2) initialize it as either test or final
3) run it and either test or finalize it

'''
# Out:
# [u'giver_username_if_known',
#  u'number_of_downvotes_of_request_at_retrieval',
#  u'number_of_upvotes_of_request_at_retrieval',
#  u'post_was_edited',
#  u'request_id',
#  u'request_number_of_comments_at_retrieval',
#  u'request_text',
#  u'request_text_edit_aware',
#  u'request_title',
#  u'requester_account_age_in_days_at_request',
#  u'requester_account_age_in_days_at_retrieval',
#  u'requester_days_since_first_post_on_raop_at_request',
#  u'requester_days_since_first_post_on_raop_at_retrieval',
#  u'requester_number_of_comments_at_request',
#  u'requester_number_of_comments_at_retrieval',
#  u'requester_number_of_comments_in_raop_at_request',
#  u'requester_number_of_comments_in_raop_at_retrieval',
#  u'requester_number_of_posts_at_request',
#  u'requester_number_of_posts_at_retrieval',
#  u'requester_number_of_posts_on_raop_at_request',
#  u'requester_number_of_posts_on_raop_at_retrieval',
#  u'requester_number_of_subreddits_at_request',
#  u'requester_received_pizza',
#  u'requester_subreddits_at_request',
#  u'requester_upvotes_minus_downvotes_at_request',
#  u'requester_upvotes_minus_downvotes_at_retrieval',
#  u'requester_upvotes_plus_downvotes_at_request',
#  u'requester_upvotes_plus_downvotes_at_retrieval',
#  u'requester_user_flair',
#  u'requester_username',
#  u'unix_timestamp_of_request',
#  u'unix_timestamp_of_request_utc']
#
#
# request_text_edit_aware
# request_title
#
#
#                              request_text_edit_aware  \
# 0  Hi I am in need of food for my 4 children we a...
# 1  I spent the last money I had on gas today. Im ...
# 2  My girlfriend decided it would be a good idea ...
# 3  It's cold, I'n hungry, and to be completely ho...
# 4  hey guys:\n I love this sub. I think it's grea...
#
#                                        request_title
# 0            Request Colorado Springs Help Us Please
# 1  [Request] California, No cash and I could use ...
# 2  [Request] Hungry couple in Dundee, Scotland wo...
# 3  [Request] In Canada (Ontario), just got home f...
# 4  [Request] Old friend coming to visit. Would LO...
#
#
# <type 'numpy.ndarray'>
# (3030L, 2L)
#
#
# (3030L,)   (1010L,)   (4040L,)
#
#
# (3030L,)   (3030L,)   (3030L, 2L)
# '\nTo use:\n1) instantiate your model class\n2) initialize it as either test or final\n3) run it and either test or finalize it\n\n'

# %%
class StackedRegression():
    '''
    Stacking with logistic regression.
    Makes a linear combination of outputs of other models
    http://link.springer.com/article/10.1007%2FBF00117832
    '''
    raise NotImplementedError("Need a 28 hour day")

# %% [markdown]
# <a id="part7"></a>
# ## 7. Ensembling Attempt

# %% [markdown]
# <a id="part7a"></a>
# ### a. Data Helper Scripts

# %%
# BASIC NUMERIC STUFF

class NumericExtractor:
    def __init__(self, cols):
        self.cols = cols

    def transform(self, data):
        return normalize(np.asarray(data[self.cols]))

    def fit(self, *_):
        return self

# TEXT STUFF

class TextExtractor:
  def __init__(self, column):
    self.column = column

  def transform(self, data):
    return np.asarray(data[self.column])

  def fit(self, *_):
    return self

class DenseTransformer:
    def transform(self, X, y=None, **fit_params):
        return X.todense()

    def fit_transform(self, X, y=None, **fit_params):
        self.fit(X, y, **fit_params)
        return self.transform(X)

    def fit(self, X, y=None, **fit_params):
        return self

def better_preprocessor(s):
        st = PorterStemmer()
        chkr = enchant.checker.SpellChecker("en_US")
        #print s
        ####s = strip_accents_unicode(s).lower() #make everything lowercase
        s = re.sub('[?,-/><=+_!.:()]',' ',s) #turn a lot of punctuations into spaces
        s = ' '.join(s.split()) #remove excess white space
        s = " ".join(word for word in s.split() if chkr.check(word) == True)
        s = " ".join(st.stem(word) for word in s.split(" "))
        s = re.sub('[\']','',s) #remove apostrophes
        #print s
        return s

# %% [markdown]
# <a id="part7b"></a>
# ### b. Ensembling Script

# %%
# ENSEMBLE STUFF
# NOTE I DID NOT WRITE THIS! 
# FOUND HERE http://sebastianraschka.com/Articles/2014_ensemble_classifier.html

class EnsembleClassifier(BaseEstimator, ClassifierMixin, TransformerMixin):
    """ Soft Voting/Majority Rule classifier for unfitted clfs.

    Parameters
    ----------
    clfs : array-like, shape = [n_classifiers]
      A list of classifiers.
      Invoking the `fit` method on the `VotingClassifier` will fit clones
      of those original classifiers that will be stored in the class attribute
      `self.clfs_`.

    voting : str, {'hard', 'soft'} (default='hard')
      If 'hard', uses predicted class labels for majority rule voting.
      Else if 'soft', predicts the class label based on the argmax of
      the sums of the predicted probalities, which is recommended for
      an ensemble of well-calibrated classifiers.

    weights : array-like, shape = [n_classifiers], optional (default=`None`)
      Sequence of weights (`float` or `int`) to weight the occurances of
      predicted class labels (`hard` voting) or class probabilities
      before averaging (`soft` voting). Uses uniform weights if `None`.

    Attributes
    ----------
    classes_ : array-like, shape = [n_predictions]

    Examples
    --------
    >>> import numpy as np
    >>> from sklearn.linear_model import LogisticRegression
    >>> from sklearn.naive_bayes import GaussianNB
    >>> from sklearn.ensemble import RandomForestClassifier
    >>> clf1 = LogisticRegression(random_state=1)
    >>> clf2 = RandomForestClassifier(random_state=1)
    >>> clf3 = GaussianNB()
    >>> X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
    >>> y = np.array([1, 1, 1, 2, 2, 2])
    >>> eclf1 = VotingClassifier(clfs=[clf1, clf2, clf3], voting='hard')
    >>> eclf1 = eclf1.fit(X, y)
    >>> print(eclf1.predict(X))
    [1 1 1 2 2 2]
    >>> eclf2 = VotingClassifier(clfs=[clf1, clf2, clf3], voting='soft')
    >>> eclf2 = eclf2.fit(X, y)
    >>> print(eclf2.predict(X))
    [1 1 1 2 2 2]
    >>> eclf3 = VotingClassifier(clfs=[clf1, clf2, clf3],
    ...                          voting='soft', weights=[2,1,1])
    >>> eclf3 = eclf3.fit(X, y)
    >>> print(eclf3.predict(X))
    [1 1 1 2 2 2]
    >>>
    """
    def __init__(self, clfs, voting='hard', weights=None):
        
        self.clfs = clfs
        self.named_clfs = {key:value for key,value in _name_estimators(clfs)}
        self.voting = voting
        self.weights = weights
        

    def fit(self, X, y):
        """ Fit the clfs.

        Parameters
        ----------
        X : {array-like, sparse matrix}, shape = [n_samples, n_features]
            Training vectors, where n_samples is the number of samples and
            n_features is the number of features.

        y : array-like, shape = [n_samples]
            Target values.

        Returns
        -------
        self : object
        """
        if isinstance(y, np.ndarray) and len(y.shape) > 1 and y.shape[1] > 1:
            raise NotImplementedError('Multilabel and multi-output'\
                                      ' classification is not supported.')

        if self.voting not in ('soft', 'hard'):
            raise ValueError("Voting must be 'soft' or 'hard'; got (voting=%r)"
                             % voting)

        if self.weights and len(self.weights) != len(self.clfs):
            raise ValueError('Number of classifiers and weights must be equal'
                             '; got %d weights, %d clfs'
                             % (len(self.weights), len(self.clfs)))

        self.le_ = LabelEncoder()
        self.le_.fit(y)
        self.classes_ = self.le_.classes_
        self.clfs_ = []
        for clf in self.clfs:
            fitted_clf = clone(clf).fit(X, self.le_.transform(y))
            self.clfs_.append(fitted_clf)
        return self

    def predict(self, X):
        """ Predict class labels for X.

        Parameters
        ----------
        X : {array-like, sparse matrix}, shape = [n_samples, n_features]
            Training vectors, where n_samples is the number of samples and
            n_features is the number of features.

        Returns
        ----------
        maj : array-like, shape = [n_samples]
            Predicted class labels.
        """
        if self.voting == 'soft':

            maj = np.argmax(self.predict_proba(X), axis=1)

        else:  # 'hard' voting
            predictions = self._predict(X)

            maj = np.apply_along_axis(
                                      lambda x:
                                      np.argmax(np.bincount(x,
                                                weights=self.weights)),
                                      axis=1,
                                      arr=predictions)

        maj = self.le_.inverse_transform(maj)
        return maj

    def predict_proba(self, X):
        """ Predict class probabilities for X.

        Parameters
        ----------
        X : {array-like, sparse matrix}, shape = [n_samples, n_features]
            Training vectors, where n_samples is the number of samples and
            n_features is the number of features.

        Returns
        ----------
        avg : array-like, shape = [n_samples, n_classes]
            Weighted average probability for each class per sample.
        """
        avg = np.average(self._predict_probas(X), axis=0, weights=self.weights)
        return avg

    def transform(self, X):
        """ Return class labels or probabilities for X for each estimator.

        Parameters
        ----------
        X : {array-like, sparse matrix}, shape = [n_samples, n_features]
            Training vectors, where n_samples is the number of samples and
            n_features is the number of features.

        Returns
        -------
        If `voting='soft'`:
          array-like = [n_classifiers, n_samples, n_classes]
            Class probabilties calculated by each classifier.
        If `voting='hard'`:
          array-like = [n_classifiers, n_samples]
            Class labels predicted by each classifier.
        """
        if self.voting == 'soft':
            return self._predict_probas(X)
        else:
            return self._predict(X)

    def get_params(self, deep=True):
        """ Return estimator parameter names for GridSearch support"""
        if not deep:
            return super(EnsembleClassifier, self).get_params(deep=False)
        else:
            out = self.named_clfs.copy()
            for name, step in six.iteritems(self.named_clfs):
                for key, value in six.iteritems(step.get_params(deep=True)):
                    out['%s__%s' % (name, key)] = value
            return out

    def _predict(self, X):
        """ Collect results from clf.predict calls. """
        return np.asarray([clf.predict(X) for clf in self.clfs_]).T

    def _predict_probas(self, X):
        """ Collect results from clf.predict calls. """
        return np.asarray([clf.predict_proba(X) for clf in self.clfs_])

# %% [markdown]
# <a id="part7c"></a>
# ### c. Pipelines and Testing

# %%
'''
Set up a pipeline that examines message and title
'''

# Grab all the numeric columns
numeric_columns = [master_data.getTestColumnNames()[i] for i in [4,5,6,7,8,9,10,12,13]] 

class ModelTransformer(TransformerMixin):
    """ A wrapper for scikit-learn's Pipeline class that takes a classifier
        and makes it behave like a transformer.
    """
    def __init__(self, model):
        self.model = model

    def fit(self, *args, **kwargs):
        self.model.fit(*args, **kwargs)
        return self

    def transform(self, X, **transform_params):
        return pd.DataFrame(self.model.predict(X))

msg_pipeline_prp = Pipeline([
  ('features', FeatureUnion([
    ('message', Pipeline([
      ('extract_msg', TextExtractor('request_text_edit_aware')),
      ('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], preprocessor=better_preprocessor)),
      #('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], max_df=.45, min_df=.01)),
      ('densify', DenseTransformer())
    ]))
  ])),
  ('clf', LogisticRegression())
])
    
text_pipeline_lor = Pipeline([
  ('features', FeatureUnion([
    ('message', Pipeline([
      ('extract_msg', TextExtractor('request_text_edit_aware')),
      #('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], preprocessor=better_preprocessor)),
      ('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], max_df=.45, min_df=.01)),
      ('densify', DenseTransformer())
    ])),
    ('title', Pipeline([
      ('extract_title', TextExtractor('request_title')),
      ('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], max_df=.4, min_df=.1)),
      ('densify', DenseTransformer())
    ])),
  ])),
  ('classifiers', FeatureUnion([
    ('knn', ModelTransformer(KNeighborsClassifier(n_neighbors=5))),
    ('dtr',ModelTransformer(DecisionTreeClassifier())),
    ('rfr', ModelTransformer(RandomForestClassifier())),
    ('lor', ModelTransformer(LogisticRegression()))
  ])),
  ('clf', LogisticRegression())
])

text_pipeline_gbc = Pipeline([
  ('features', FeatureUnion([
    ('message', Pipeline([
      ('extract_msg', TextExtractor('request_text_edit_aware')),
      #('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], preprocessor=better_preprocessor)),
      ('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], max_df=.45, min_df=.01)),
      ('densify', DenseTransformer())
    ])),
    ('title', Pipeline([
      ('extract_title', TextExtractor('request_title')),
      ('counts', CountVectorizer(stop_words = ['pizza', 'pizzas', 'request', 'requests'], max_df=.4, min_df=.1)),
      ('densify', DenseTransformer())
    ])),
  ])),
  ('gbc', GradientBoostingClassifier(n_estimators = 20, max_depth = 5, min_samples_split=10))
])

numeric_pipeline_rf = Pipeline([
  ('features', FeatureUnion([
    ('extract_numeric', NumericExtractor(numeric_columns)),
  ])),
  ('pca', PCA(n_components=3)),
  ('rfr', RandomForestClassifier(criterion = 'entropy',n_estimators=40))
])

numeric_pipeline_dt = Pipeline([
  ('features', FeatureUnion([
    ('extract_numeric', NumericExtractor(numeric_columns)),
  ])),
  ('dtr', DecisionTreeClassifier(criterion='entropy',max_depth=5))
])

# ENTER THE NAMES OF THE PIPELINES HERE
ensemble_models = [msg_pipeline_prp, text_pipeline_lor, numeric_pipeline_rf, numeric_pipeline_dt]

def test_eclf():
    
    # Get the score when the pipelines are ensembled
    
    train_data = master_data.getTrain()
    train_targets = train_data['requester_received_pizza'].values
    dev_data = master_data.getDev()
    dev_targets = dev_data['requester_received_pizza'].values
    
    eclf = EnsembleClassifier(ensemble_models)
    eclf.fit(train_data, train_targets)
    predicted_eclf = eclf.predict(dev_data)
    #scores = cross_val_score(eclf, train_data, train_targets, cv=5, scoring='roc_auc')
    #print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
    print metrics.roc_auc_score(dev_targets,predicted_eclf)
    
def test_pipeline(pipeline_name):
    
    # Get the scores separately for each pipeline
    
    train_data = master_data.getTrain()
    train_targets = train_data['requester_received_pizza'].values
    dev_data = master_data.getDev()
    dev_targets = dev_data['requester_received_pizza'].values
    
    clf = pipeline_name.fit(train_data, train_targets)

    predicted = clf.predict(dev_data)

    print metrics.roc_auc_score(dev_targets,predicted)

def final_pipeline(filename):
    
    # Write a result (not currently working)
    
    train_data = master_data.getTrainFull()
    train_targets = train_data['requester_received_pizza'].values
    
    eclf = EnsembleClassifier(ensemble_models)
    eclf.fit(train_data, train_targets)

    test_data = master_data.getTest()
    test_requests = test_data['request_id']
    
    predicted_eclf = eclf.predict(dev_data)
    pred_series = pd.Series(predicted_eclf.astype(int),name="requester_received_pizza")
    out = pd.concat([test_requests,pred_series], axis=1)
    out.to_csv(filename,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-95a217032609> in <module>()
#       6 numeric_columns = [master_data.getTestColumnNames()[i] for i in [4,5,6,7,8,9,10,12,13]]
#       7
# ----> 8 class ModelTransformer(TransformerMixin):
#       9     """ A wrapper for scikit-learn's Pipeline class that takes a classifier
#      10         and makes it behave like a transformer.
#
# NameError: name 'TransformerMixin' is not defined

# %%
# Get AUC of ensemble model
# See for methodology http://sebastianraschka.com/Articles/2014_ensemble_classifier.html
test_eclf()

# %%
# Get AUC of a pipeline on train/dev data
test_pipeline(text_pipeline_gbc)

# %%
# Get AUC of each pipeline individually
for pipe in ensemble_models:
    print pipe
    test_pipeline(pipe)

# %%
# Put together a submission
final_pipeline('eclf_final.csv')

# %% [markdown]
# <a id="part8"></a>
# ## 8. Final Submission

# %% [markdown]
# The best submission we had ended up being a spherical GMM model with 6 components using 3-component PCA on solely numeric data. Surprisingly, this outperformed every text model (despite text being the main focus of most of our experiments) and every attempt at ensembling. The code for this model is repeated below:

# %%
class PCAGMM(Model):
    '''
    PCA followed by GMM
    '''
    def __init__(self,dfFit,dfPredict,k=3,cov_type='spherical',n=6,**kwargs):
        Model.__init__(self,dfFit,dfPredict)
        self.classifier = GMM
        #hyperparams
        self.k = k #number of PCA dimensions
        self.cov_type = cov_type
        self.n = n #number of GMM components
        #how to process data
        f1,l1 = fe.gourmetNumericFeatures(self.dfFit)
        p1,_ = fe.gourmetNumericFeatures(self.dfPredict)
        
        self.feature_names = self.conductPCA(f1,p1)
        """
        #Ensemble
        elr = EnsembleLR(dfFit,dfFit)
        elr.run_model()
        f2 = elr.prediction
        
        elr2 = EnsembleLR(dfFit,dfPredict)
        elr2.run_model()
        p2 = elr2.prediction
        
        l2 = ['ELR prediction']
        
        #Combine
        f_c = np.column_stack((f1,f2))
        p_c = np.column_stack((p1,p2))
        self.feature_names = self.conductPCA(f_c,p_c) + l2
        """
    def run_model(self):
        #predict
        self.prediction = self.classify()    
    
    def calcNumberParams(self,k,cm_type,n):
        '''
        Calculates number of parameters in model
        '''
        if cm_type=='spherical':
            return (k+1)*n*2
        elif cm_type=='tied':
            return (k)*n*2 + (k**2)*1*2 #first term is for mean vector, second is for cov matrix
        elif cm_type=='diag':
            return (k+k)*n*2
        elif cm_type=='full':
            return (k+k**2)*n*2
        else:
            raise ValueError('Invalid covariance matrix type')
    
    def conductPCA(self,f,p):
        #firstly normalize
        f = normalize(f)
        p = normalize(p)
        
        #transform data
        pca = PCA(n_components=self.k)
        fit_data_dimk = pca.fit_transform(f)
        predict_data_dimk = pca.transform(p)
        
        #save as instance vars
        self.fit_data = fit_data_dimk
        self.predict_data = predict_data_dimk
        return ['No Name']*self.k

    def classify(self):
     
        #separate into positive and negative classification examples
        fit_data_positive = self.fit_data[self.fit_labels,:]
        fit_data_negative = self.fit_data[~self.fit_labels,:]
        
        #fit GMMs
        g_pos = GMM(n_components=self.n,covariance_type=self.cov_type)
        g_pos.fit(fit_data_positive)
        g_neg = GMM(n_components=self.n,covariance_type=self.cov_type)
        g_neg.fit(fit_data_negative)

        #predict
        p_pos = g_pos.score(self.predict_data)
        p_neg = g_neg.score(self.predict_data)
        return (p_pos>p_neg).astype(int)

# %%
final_model = PCAGMM(master_data.getTrain(),master_data.getDev())
final_model.run_model()
print final_model.test()
# Out:
# 0.588047327285

# %%
final_model.writeSubmission('PCAGMM_submission.csv')
# Out:
# [0 1 1 ..., 1 0 1]
# Written to File!

# %% [markdown]
# <a id="part9"></a>
# ## 9. Error Analysis

# %% [markdown]
# ### Checking our final model

# %%
model_predict = final_model.getPrediction()
dev_labels = master_data.dfDev['requester_received_pizza'].values

# %%
# A basic classification report
print classification_report(dev_labels, model_predict)
# Out:
#              precision    recall  f1-score   support
#
#       False       0.83      0.46      0.59       761
#        True       0.30      0.71      0.43       249
#
# avg / total       0.70      0.52      0.55      1010

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(2)
    plt.xticks(tick_marks, ['no pizza','pizza'], rotation=45)
    plt.yticks(tick_marks, ['no pizza','pizza'])
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Confusion Matrix
# Confusion Matrix
cm = confusion_matrix(dev_labels,model_predict)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print(cm)
print(cm_normalized)
plt.figure()
plot_confusion_matrix(cm)
plt.figure()
plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')
plt.show()
# Out:
# [[351 410]
#  [ 71 178]]
# [[ 0.46123522  0.53876478]
#  [ 0.28514056  0.71485944]]

# %% [markdown]
# From the confusion matrix and classification report, it's clear that our biggest problem is predicting "pizza" when the user did not in fact get a pizza.

# %%
pca_dev = final_model.predict_data
pizza = np.where(dev_labels==1)
no_pizza = np.where(dev_labels==0)

# %%
# Please excuse the awfulness of this code. It's 2am.
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_dev[pizza, 0], pca_dev[pizza, 1], pca_dev[pizza, 2], c='g', marker='o')
ax.scatter(pca_dev[no_pizza, 0], pca_dev[no_pizza, 1], pca_dev[no_pizza, 2], c='r', marker='o')
ax.set_xlabel('PC 1')
ax.set_ylabel('PC 2')
ax.set_zlabel('PC 3')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_dev[pizza, 0], pca_dev[pizza, 2], pca_dev[pizza, 1], c='g', marker='o')
ax.scatter(pca_dev[no_pizza, 0], pca_dev[no_pizza, 2], pca_dev[no_pizza, 1], c='r', marker='o')
ax.set_xlabel('PC 1')
ax.set_ylabel('PC 3')
ax.set_zlabel('PC 2')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_dev[pizza, 1], pca_dev[pizza, 0], pca_dev[pizza, 2], c='g', marker='o')
ax.scatter(pca_dev[no_pizza, 1], pca_dev[no_pizza, 0], pca_dev[no_pizza, 2], c='r', marker='o')
ax.set_xlabel('PC 2')
ax.set_ylabel('PC 1')
ax.set_zlabel('PC 3')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_dev[pizza, 1], pca_dev[pizza, 2], pca_dev[pizza, 0], c='g', marker='o')
ax.scatter(pca_dev[no_pizza, 1], pca_dev[no_pizza, 2], pca_dev[no_pizza, 0], c='r', marker='o')
ax.set_xlabel('PC 2')
ax.set_ylabel('PC 3')
ax.set_zlabel('PC 1')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_dev[pizza, 2], pca_dev[pizza, 0], pca_dev[pizza, 1], c='g', marker='o')
ax.scatter(pca_dev[no_pizza, 2], pca_dev[no_pizza, 0], pca_dev[no_pizza, 1], c='r', marker='o')
ax.set_xlabel('PC 3')
ax.set_ylabel('PC 1')
ax.set_zlabel('PC 2')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_dev[pizza, 2], pca_dev[pizza, 1], pca_dev[pizza, 0], c='g', marker='o')
ax.scatter(pca_dev[no_pizza, 2], pca_dev[no_pizza, 1], pca_dev[no_pizza, 0], c='r', marker='o')
ax.set_xlabel('PC 3')
ax.set_ylabel('PC 2')
ax.set_zlabel('PC 1')

# %% [markdown]
# No matter how we look at it, there are no obviously visible clusters here. Most requests, successful (group) or not (red), are grouped closely together with a few outliers.

# %% [markdown]
# ### Examining the failures of our best text model

# %%
text_predict = preproc_model.getPrediction()

# %%
# A basic classification report
print classification_report(dev_labels, text_predict)
# Out:
#              precision    recall  f1-score   support
#
#       False       0.78      0.86      0.82       761
#        True       0.38      0.27      0.32       249
#
# avg / total       0.68      0.71      0.69      1010

# %%
# Confusion Matrix
cm = confusion_matrix(dev_labels,text_predict)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print(cm)
print(cm_normalized)
plt.figure()
plot_confusion_matrix(cm)
plt.figure()
plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')
plt.show()
# Out:
# [[651 110]
#  [181  68]]
# [[ 0.85545335  0.14454665]
#  [ 0.72690763  0.27309237]]

# %% [markdown]
# This model was clearly better at accurate predictions, but that's because it simply predicted the larger class more often (hence its lower AUC score). In cases where it did predict pizzas, it was wrong twice as often as it was right. It would seem that combining these two models together would result in a balance... but this was not our experience when we tried.

# %%
printWorstPredictions(preproc_model)
# Out:
# ...Document #446...
# True Label: False
# Predicted Label: True
# Data:
# "[Request] Indiana, USA Would love some pizza for what seems to be a very busy work day. I've recently been put on a rather large project from my employer. Combine that with trying to learn some light web development and trying to improve my understanding of XHTML and CSS 3.0, and I am put in a position where it seems like I have no free time. Money has been tight, so while I have a budget that keeps me fed, it's mostly just rice and other odd little things that don't cost a whole lot. I think if someone were awesome enough to gift me a pizza right now, it would help me stay sane right now. :)
#
# Would certainly pizza it forward after this large project is done near the middle of the month (right before Christmas it seems).
#
# Would also be willing to assist someone in simple or perhaps slightly complicated HTML/CSS work if requested. I'm sure I can find a little bit of time to answer questions or give advice. That's pretty much my forte. Just don't ask me about jQuery. That seems to be my kryptonite!"
#
# Metadata:
# label:  title_length , val:  87.0
# label:  req_length , val:  923.0
# label:  avg_word_length , val:  5.39766081871
# label:  title_caps_norm , val:  0.0681818181818
# label:  req_caps_norm , val:  0.0335497835498
# label:  num_numbers_norm , val:  0.0021645021645
# label:  num_currency_chars_norm , val:  0.0
# label:  num_exclamation_norm , val:  0.00108225108225
# label:  num_commas_norm , val:  0.004329004329
# label:  requester_account_age_in_days_at_request , val:  592.937361111
# label:  requester_days_since_first_post_on_raop_at_request , val:  67.9058333333
# label:  requester_number_of_comments_at_request , val:  101.0
# label:  requester_number_of_comments_in_raop_at_request , val:  1.0
# label:  requester_number_of_posts_at_request , val:  2.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  22.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  354.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  520.0
# label:  month , val:  12.0
# label:  day_of_month , val:  6.0
# label:  hour , val:  0.0
#
# ...Document #71...
# True Label: True
# Predicted Label: False
# Data:
# "[REQUEST] Working woman with an asshole roommate could use a pizza. Not sure if this is the purpose of this reddit. Please excuse the new account, I saw this on the news, what an amazing idea!
#
# I am currently living with a roommate who has just moved out of her mother's house, she has no job and her mother sends her utility and rent money. Her only responsibility is to send her mom the rent bill, and she sends half of that or pays half to the company. The problem is that this girl is SO lazy, can't be bothered to send the bills, can't be bothered to call her mom for rent and I'm under the impression she told her mom she already had a job (her mom has been chiding her for not having a job), so her mother does not feel obligated to pay this girl's bills. I have been carrying the weight of the major bills, such as electricity and rent (2x), and my paycheck is being stretched thin. To top it off, it's obvious to see where she gets her flaky attitude from...her mother REFUSES to answer my phone calls or emails. So here I am reddit, living with a girl who labels her food in the fridge so I don't touch it, and for the sake of keeping the peace...I am down to begging for a pizza X(.  I would prefer giftcards, because I would rather give out my email address than my physical address, but I will understand those who dont want to in case they believe I am a scammer.
#
#
# My email address is: Jen.Beam.1984@gmail.com"
#
# Metadata:
# label:  title_length , val:  67.0
# label:  req_length , val:  1356.0
# label:  avg_word_length , val:  5.19540229885
# label:  title_caps_norm , val:  0.117647058824
# label:  req_caps_norm , val:  0.0221075902727
# label:  num_numbers_norm , val:  0.00368459837878
# label:  num_currency_chars_norm , val:  0.0
# label:  num_exclamation_norm , val:  0.000736919675755
# label:  num_commas_norm , val:  0.0103168754606
# label:  requester_account_age_in_days_at_request , val:  0.0
# label:  requester_days_since_first_post_on_raop_at_request , val:  0.0
# label:  requester_number_of_comments_at_request , val:  0.0
# label:  requester_number_of_comments_in_raop_at_request , val:  0.0
# label:  requester_number_of_posts_at_request , val:  0.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  0.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  0.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  0.0
# label:  month , val:  7.0
# label:  day_of_month , val:  11.0
# label:  hour , val:  8.0
#
# ...Document #557...
# True Label: True
# Predicted Label: False
# Data:
# "[request] just found out i completely tore a ligament in my ankle, and got fired from my new job as a result. ive got $10 to make it through the weekend, and i could really use a hot meal and some cheering up. /: im a rugby player, and im due to start my last season for my college team in a month. sprained my ankle in july playing soccer, just got an MRI due to the persistant pain, and found out i shredded a ligament. its possibly surgical, and when i told my new boss, he said hed have to let me go because im on crutches and im 'a risky investment.' i had just paid my rent with the last of my savings yesterday before my doctors appointment, and i have $10 till tuesday [also my birthday]. just a little bummed and hungry--id really appreciate a meal, and id be happy to provide any sort of verification needed. thanks for reading. "
#
# Metadata:
# label:  title_length , val:  212.0
# label:  req_length , val:  626.0
# label:  avg_word_length , val:  5.21666666667
# label:  title_caps_norm , val:  0.0
# label:  req_caps_norm , val:  0.00478468899522
# label:  num_numbers_norm , val:  0.00318979266348
# label:  num_currency_chars_norm , val:  0.00159489633174
# label:  num_exclamation_norm , val:  0.0
# label:  num_commas_norm , val:  0.0111642743222
# label:  requester_account_age_in_days_at_request , val:  447.945219907
# label:  requester_days_since_first_post_on_raop_at_request , val:  0.0
# label:  requester_number_of_comments_at_request , val:  220.0
# label:  requester_number_of_comments_in_raop_at_request , val:  0.0
# label:  requester_number_of_posts_at_request , val:  6.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  20.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  2699.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  4093.0
# label:  month , val:  9.0
# label:  day_of_month , val:  2.0
# label:  hour , val:  11.0
#
# ...Document #779...
# True Label: False
# Predicted Label: True
# Data:
# "[Request] Hungry, just moved, no cash until tomorrow, can trade Paypal cash. Hi Reddit, I don't really like asking for help but my daughter and I just moved into our apartment a week ago and we are going through a bit of a rough patch [financially](http://i.imgur.com/9IH4v.jpg). At the moment we have [no food](http://imgur.com/a/UCUvL#0) except some condiments. My daughter is extremely hungry and words can not describe how low I feel about not being able to feed her. I really thought I planned things out well but I did not. And now she has to suffer for my screw up.
#
# As I stated [I have Paypal cash](http://imgur.com/2AO2c), but I do not have a paypal debit card, If someone would want to do a trade I'd appreciate it. If anyone can help but does not have a Paypal I can send you a [$25 Bath and body works GC](http://imgur.com/a/UCUvL#0). It is my fault that I did not plan things correctly, and this is my last option for today to make things right for my daughter. I am not in any way shape or form asking for a handout or a freebie, I just want to make a simple trade so my daughter and I can eat tonight. I'm not posting on my real account because I'm ashamed that things turned out this way and I feel I should only be here to help and not to be helped. But I can do a trade and pay it forward to make it up. If you want any more proof please don't hesitate to ask, I can give my account name and more picture, even a picture of my state ID. "
#
# Metadata:
# label:  title_length , val:  76.0
# label:  req_length , val:  1378.0
# label:  avg_word_length , val:  5.2
# label:  title_caps_norm , val:  0.038961038961
# label:  req_caps_norm , val:  0.0369833212473
# label:  num_numbers_norm , val:  0.00580130529369
# label:  num_currency_chars_norm , val:  0.000725163161711
# label:  num_exclamation_norm , val:  0.0
# label:  num_commas_norm , val:  0.00507614213198
# label:  requester_account_age_in_days_at_request , val:  0.0
# label:  requester_days_since_first_post_on_raop_at_request , val:  0.0
# label:  requester_number_of_comments_at_request , val:  0.0
# label:  requester_number_of_comments_in_raop_at_request , val:  0.0
# label:  requester_number_of_posts_at_request , val:  0.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  0.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  0.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  0.0
# label:  month , val:  8.0
# label:  day_of_month , val:  1.0
# label:  hour , val:  10.0
#
# ...Document #171...
# True Label: False
# Predicted Label: True
# Data:
# "(request) Been up all night crying, screaming, and now starving. Jacksonville FL. I'm not new to Reddit and I'm not from Jacksonville either. Sorry but I'm requesting incognito because I don't want anyone I know to find out about what's happening right now. There's a really messed up situation and I haven't even told my dad about this yet, so I don't want my friends or cousins finding out yet either because they can't keep their mouths shut.
#
# I got a surprise yesterday when a guy I've never even met greets me in the hallway of my apartment building and tells me he wants me to leave my girlfriend of 2 years. My girlfriend then confronts us both and gives me the shock of my life, she's been cheating on me with this guy, and she's pregnant, but she's 90% certain neither of us is the father! She was cheating on me with this guy, and cheating on him with someone else. I've never raised a hand to a girl and never will, I was raised better than that, but I've never been more tempted in my life to haul back and deck someone!
#
# After a two hour conversation with this dude I find out she hasn't been working for a whole year. He's been paying our electric and water since we moved into the apartment! She goes over to his house almost daily when she left me to head to work. Some days she leaves and neither of us could account for where she was. My girlfriend of 2 years is a lady of the night and has been milking 3 guys, me included and maybe more than just us, for everything we've got for years!
#
# I'm at my bros house and he's been very tolerant of all this, real step up kind of guy to take me in because I've been living with this tramp for over a year now, I got no place else to go right now. I need something to eat because neither of us has any money and he's living off noodles right now. I'll happily pay it forward on the 8th when I get paid. But for today, I need something better than noodles or black beans and rice, and I think he would appreciate it too.
#
# Sorry again for being a bit deceptive with my post. If I wasn't starving I wouldn't be spreading it around for that matter either. If anyone can help you have my gratitude.
#
# 8:30 AM. Taking a trip out and about, will be back in a few hours to check the thread.
# "
#
# Metadata:
# label:  title_length , val:  81.0
# label:  req_length , val:  2161.0
# label:  avg_word_length , val:  5.15751789976
# label:  title_caps_norm , val:  0.0487804878049
# label:  req_caps_norm , val:  0.0189639222942
# label:  num_numbers_norm , val:  0.00416281221092
# label:  num_currency_chars_norm , val:  0.0
# label:  num_exclamation_norm , val:  0.00185013876041
# label:  num_commas_norm , val:  0.00647548566142
# label:  requester_account_age_in_days_at_request , val:  0.0
# label:  requester_days_since_first_post_on_raop_at_request , val:  0.0
# label:  requester_number_of_comments_at_request , val:  0.0
# label:  requester_number_of_comments_in_raop_at_request , val:  0.0
# label:  requester_number_of_posts_at_request , val:  0.0
# label:  requester_number_of_posts_on_raop_at_request , val:  0.0
# label:  requester_number_of_subreddits_at_request , val:  0.0
# label:  requester_upvotes_minus_downvotes_at_request , val:  0.0
# label:  requester_upvotes_plus_downvotes_at_request , val:  0.0
# label:  month , val:  10.0
# label:  day_of_month , val:  30.0
# label:  hour , val:  21.0

# %% [raw]
# Interestingly enough, the worst predicted example (down the bottom) has remained with us for the entire tuning of the logistic regression models. Since she didn't get a pizza in real life, I'm tempted to just buy her one to make my model right.
